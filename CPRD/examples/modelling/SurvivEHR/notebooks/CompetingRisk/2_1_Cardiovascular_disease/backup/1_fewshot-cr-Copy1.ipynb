# %% [markdown]
# # CPRD Notebook:
# ## Evaluation of fine-tuning the pre-trained SurvivEHR-CR model on a supervised cohort study.
#
# Cohort study: predicting Cardiovascular Disease in a Type 2 Diabetes Mellitus population.
#
# This notebook quantifies the performance obtained when fine-tuning the pre-trained model to a sub-population.

# %%
import os
from pathlib import Path
import sys
node_type = os.getenv('BB_CPU')
venv_dir = f'/rds/homes/g/gaddcz/Projects/CPRD/virtual-envTorch2.0-{node_type}'
venv_site_pkgs = Path(venv_dir) / 'lib' / f'python{sys.version_info.major}.{sys.version_info.minor}' / 'site-packages'
if venv_site_pkgs.exists():
    sys.path.insert(0, str(venv_site_pkgs))
    print(f"Added path '{venv_site_pkgs}' at start of search paths.")
else:
    print(f"Path '{venv_site_pkgs}' not found. Check that it exists and/or that it exists for node-type '{node_type}'.")

# %load_ext autoreload
# %autoreload 2

print(os.getcwd())
# Out:
# Added path '/rds/homes/g/gaddcz/Projects/CPRD/virtual-envTorch2.0-icelake/lib/python3.10/site-packages' at start of search paths.
# /rds/homes/g/gaddcz/Projects/CPRD/examples/modelling/SurvStreamGPT/notebooks/CompetingRisk/CVD

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import logging
import wandb
from tqdm import tqdm
import pickle
from hydra import compose, initialize
from omegaconf import OmegaConf
from CPRD.examples.modelling.SurvStreamGPT.run_experiment import run
from CPRD.data.foundational_loader import FoundationalDataModule
from CPRD.src.models.survival.task_heads.causal import SurvStreamGPTForCausalModelling

import time
import pyarrow.dataset as ds
import pyarrow.parquet as pq
import os
import polars as pl
pl.Config.set_tbl_rows(10000)
import pandas as pd
pd.options.display.max_rows = 10000

torch.manual_seed(1337)
torch.set_float32_matmul_precision('medium')

logging.basicConfig(level=logging.INFO)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# device = "cpu"    # if more informative debugging statements are needed
print(f"Using device: {device}.")

 # TODO: define an env variable to fix for a local hpc environment issue, this shouldn't be needed
# %env SLURM_NTASKS_PER_NODE=28
# Out:
# Using device: cuda.
# env: SLURM_NTASKS_PER_NODE=28

# %% [markdown]
# # Choosing configurations
# The default configuration is for pre-training. Here we modify as necesssary
#
# Here we choose to load in the configuration for a small **pre-trained** 11.4M parameter model, named "CR_11M". We specfiy the `fine-tune` experiment type, which will lead to running the ```SupervisedExperiment```.
#
# We tell this experiment that we want to perform training (true by default). Additionally, we do choose to perform testing (true by default). As this is a supervised model, this tests the ability to predict the outcomes of interest. In this notebook, this is chosen to be those of the cohort study for predicting Cardiovascular Disease in a Type 2 Diabetes Mellitus population, and we add the folder containing this dataset to the configuration.
#
# ```Note: As this is a supervised dataset, we need to tell the DataModule that the last event observed is a target and must be stripped. This is done by passing a list of targets to the configuration, overriding the null default. This lets the DataModule know that it should process batches as supervised.```
#
# We set the number of workers to be appropriate for the number of CPUs available to reduce bottlenecking, and tell the experiment that we do not want to limit the number of testing batches. In addition, we specify where we want any checkpoints to be saved to avoid bloating the repository.
#
# We design a new optimisation strategy for fine-tuning. Pre-training was achieved with a warmup and cosine annealing, with rates which are no appropriate for much smaller dataset sizes seen in clinical prediction models (CPMs). We here choose a simpler strategy: of ReduceOnPlateau with no warmup, increasing the number of epochs (default is 1) and reduced validation intervals, and the addition of early stopping. Additionally, as this is not a causal model we can increase the batch size. Finally, as this CPM is not trying to predict the value of any outcomes, we set the value weight to zero allowing the model to focus entirely on optimising survival outcome prediction.

# %% [markdown]
# # Small 11.4M parameter model
#
# ```
# Hypertension
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃             Test metric             ┃            DataLoader 0             ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │  Test:OutcomePerformanceMetricsctd  │         0.6980466246604919          │
# │  Test:OutcomePerformanceMetricsibs  │         0.09058867272886643         │
# │ Test:OutcomePerformanceMetricsinbll │         0.3116109046404026          │
# │              test_loss              │         1.3693411350250244          │
# └─────────────────────────────────────┴─────────────────────────────────────┘
# CVD (old)
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃             Test metric             ┃            DataLoader 0             ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │  Test:OutcomePerformanceMetricsctd  │         0.6582537293434143          │
# │  Test:OutcomePerformanceMetricsibs  │        0.033626483186099766         │
# │ Test:OutcomePerformanceMetricsinbll │         0.14357818411009718         │
# │              test_loss              │          9.273333549499512          │
# │          test_loss_desurv           │          9.273333549499512          │
# └─────────────────────────────────────┴─────────────────────────────────────┘
# ```

# %%
pre_trained_models = ["CR_11M_24_11_01_big_posencscale_", "NULL"]
experiments = ["hypertension", "cvd"] 

for pre_trained_model in pre_trained_models:

    for experiment in experiments:
    
        # load the configuration file, override any settings 
        with initialize(version_base=None, config_path="../../../confs", job_name="testing_notebook"):
            cfg = compose(config_name="config_CompetingRisk37M", 
                          overrides=[# Experiment setup
                                     "experiment.type='few-shot'",
                                     f"experiment.run_id='{pre_trained_model}'",
                                     f"experiment.fine_tune_id='{experiment}-few-shot-time_test'",
                                     "experiment.train=True",
                                     "experiment.test=True",
                                     # Dataloader
                                     "data.meta_information_path=/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle",
                                     "data.min_workers=12",
                                     # Optimiser
                                     "optim.num_epochs=5",
                                     "optim.scheduler=ReduceOnPlateau",
                                     "optim.scheduler_warmup=False",
                                     "optim.learning_rate=1e-3", #3e-4",
                                     "optim.val_check_interval=0.1",
                                     "optim.limit_val_batches=0.25",
                                     "optim.limit_test_batches=null",
                                     "optim.early_stop=True",
                                     "optim.early_stop_patience=1",
                                     # Head
                                     "head.surv_weight=1",
                                     "head.value_weight=0",
                                    ]
                         )     
    
        
        match experiment.lower():
            case "cvd":
                cfg.data.path_to_ds="/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/"
                cfg.experiment.fine_tune_outcomes=["IHDINCLUDINGMI_OPTIMALV2", "ISCHAEMICSTROKE_V2", "MINFARCTION", "STROKEUNSPECIFIED_V2", "STROKE_HAEMRGIC"]
            case "hypertension":
                cfg.data.path_to_ds="/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_Hypertension/"
                cfg.experiment.fine_tune_outcomes=["HYPERTENSION"]
                
        wandb.finish()
        experiment, dm = run(cfg)
        print(f"Loaded model with {sum(p.numel() for p in experiment.model.parameters())/1e6} M parameters")
        wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.008 MB of 0.011 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.722728…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Scheduler</td><td>▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▇██▇▇▇▆▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▂▂▃▃▄▄▅▅▅▅▆▆▇▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Scheduler</td><td>0.001</td></tr><tr><td>epoch</td><td>0</td></tr><tr><td>train_loss</td><td>-3.58969</td></tr><tr><td>trainer/global_step</td><td>179</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">CR_11M_24_11_01_big_posencscale__hypertension-few-shot-time_test_a</strong>: <a href="https://wandb.ai/cwlgadd/SurvivEHR/runs/15irai40" target="_blank">https://wandb.ai/cwlgadd/SurvivEHR/runs/15irai40</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/wandb/run-20241120_135707-15irai40/logs</code>
# INFO:root:Running cr on 72 CPUs and 1 GPUs
# INFO:root:====================================================================================================
# INFO:root:# Loading DataModule for dataset /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_Hypertension/. This will be loaded in supervised form.
# INFO:root:====================================================================================================
# INFO:root:Creating supervised collator for DataModule
# INFO:root:Using meta information from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle
# INFO:root:Using train file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_Hypertension/file_row_count_dict_train.pickle
# INFO:root:Using test file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_Hypertension/file_row_count_dict_test.pickle
# INFO:root:Using val file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_Hypertension/file_row_count_dict_val.pickle
# INFO:root:Tokenzier created based on 7,555,415,275 tokens
# INFO:root:Using tabular tokenizer, created from meta information and containing 265 tokens
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_Hypertension/split=train/ dataset, with 572,096 samples
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_Hypertension/split=test/ dataset, with 35,758 samples
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_Hypertension/split=val/ dataset, with 33,280 samples
# INFO:root:is_decoder: true
# data:
#   batch_size: 64
#   unk_freq_threshold: 0.0
#   min_workers: 12
#   global_diagnoses: false
#   path_to_db: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/
#   path_to_ds: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_Hypertension/
#   meta_information_path: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle
#   subsample_training: null
# experiment:
#   type: few-shot
#   project_name: SurvivEHR
#   run_id: CR_11M_24_11_01_big_posencscale_
#   fine_tune_id: hypertension-few-shot-time_test
#   train: true
#   test: true
#   verbose: true
#   seed: 1337
#   log: true
#   log_dir: /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/
#   ckpt_dir: /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/
#   fine_tune_outcomes:
#   - HYPERTENSION
# optim:
#   num_epochs: 5
#   learning_rate: 0.001
#   scheduler_warmup: false
#   scheduler: ReduceOnPlateau
#   scheduler_periods: 10000
#   learning_rate_decay: 0.8
#   val_check_interval: 0.1
#   early_stop: true
#   early_stop_patience: 1
#   log_every_n_steps: 20
#   limit_val_batches: 0.25
#   limit_test_batches: null
# transformer:
#   block_type: Neo
#   block_size: 256
#   n_layer: 10
#   n_head: 8
#   n_embd: 1024
#   layer_norm_bias: false
#   attention_type: global
#   bias: true
#   dropout: 0.0
#   attention_dropout: 0.0
#   resid_dropout: 0.0
#   private_heads: 0
# head:
#   SurvLayer: cr
#   surv_weight: 1
#   tokens_for_univariate_regression:
#   - 84
#   - 86
#   - 107
#   - 154
#   - 42
#   - 231
#   - 63
#   - 85
#   - 247
#   - 51
#   - 103
#   - 146
#   - 66
#   - 172
#   - 152
#   - 261
#   - 235
#   - 193
#   - 184
#   - 101
#   - 223
#   - 135
#   - 226
#   - 202
#   - 145
#   - 244
#   - 165
#   - 64
#   - 185
#   - 238
#   - 220
#   - 232
#   - 240
#   - 237
#   - 17
#   - 239
#   - 217
#   - 118
#   - 219
#   - 251
#   - 25
#   - 150
#   - 111
#   - 102
#   - 15
#   - 110
#   - 130
#   - 128
#   - 122
#   - 99
#   - 77
#   - 96
#   - 140
#   - 50
#   - 80
#   - 108
#   - 138
#   - 27
#   - 139
#   - 125
#   - 117
#   - 105
#   - 109
#   - 243
#   - 236
#   - 208
#   - 98
#   - 176
#   - 209
#   - 194
#   - 61
#   - 73
#   - 214
#   - 206
#   - 229
#   - 225
#   - 183
#   - 186
#   - 215
#   - 187
#   - 248
#   - 179
#   - 163
#   - 180
#   - 181
#   - 153
#   - 245
#   - 54
#   - 246
#   - 112
#   - 212
#   - 141
#   - 204
#   - 227
#   - 173
#   - 55
#   - 119
#   - 262
#   - 127
#   - 71
#   - 59
#   - 144
#   - 113
#   - 170
#   - 241
#   - 168
#   - 47
#   - 159
#   value_weight: 0
#
# INFO:root:====================================================================================================
# INFO:root:# Few-shot learning experiment.
# INFO:root:====================================================================================================
# INFO:root:Creating new few-shot model at the path /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-time_test.ckpt. This is initialised from a pre-trained causal model, which can be found at checkpoint /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale_.ckpt.
# INFO:root:Running few-shot experiment with outcomes {'HYPERTENSION': 129}
# INFO:root:Loading from checkpoint /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale_.ckpt
# INFO:root:Using Temporal Positional Encoding. This module uses the patient's age at an event within their time series.
# INFO:root:Using Competing-Risk DeSurv head.
# INFO:root:In generation forwarding DeSurv on the grid between [0.0, 1.0] with 1000 intervals
# INFO:root:Fixing Transformer parameters and training only head.
# /rds/bear-apps/2022a/EL8-ice/software/PyTorch-Lightning/2.1.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/pytorch_lightning/core/saving.py:173: Found keys that are in the model state dict but not in the checkpoint: ['scaled_output_time']
# INFO:root:Learning new time scale
# INFO:root:Freezing all parameters, and training only output time scalar.
# INFO:root:Created Performance metric callback. Calculating metrics for dict_keys([129]) with map {129: 128}
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# INFO:root:Training model.
# wandb version 0.18.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.6
# Run data is saved locally in <code>/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/wandb/run-20241120_144701-257p9di4</code>
# Syncing run <strong><a href="https://wandb.ai/cwlgadd/SurvivEHR/runs/257p9di4" target="_blank">CR_11M_24_11_01_big_posencscale__hypertension-few-shot-time_test_a</a></strong> to <a href="https://wandb.ai/cwlgadd/SurvivEHR" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# /rds/bear-apps/2022a/EL8-ice/software/PyTorch-Lightning/2.1.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:630: Checkpoint directory /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:root:Using ReduceLROnPlateau scheduler
# INFO:root:Not using warm-up in scheduler
#
#   | Name         | Type                            | Params
# -----------------------------------------------------------------
# 0 | model        | SurvStreamGPTForCausalModelling | 129 M
#   | other params | n/a                             | 1
# -----------------------------------------------------------------
# 1         Trainable params
# 129 M     Non-trainable params
# 129 M     Total params
# 517.425   Total estimated model params size (MB)
# SLURM auto-requeueing enabled. Setting signal handlers.
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# INFO:root:scaling by Parameter containing:
# tensor(-1.3863, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.3863, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.3863, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.3863, device='cuda:0', requires_grad=True)
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:root:scaling by Parameter containing:
# tensor(-1.3863, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.3873, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.3882, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.3892, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.3902, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.3912, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.3922, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.3931, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.3941, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.3951, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.3960, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.3969, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.3978, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.3987, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.3996, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4005, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4015, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4024, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4034, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4043, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4052, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4061, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4071, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4080, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4089, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4098, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4107, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4117, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4126, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4136, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4146, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4155, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4165, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4175, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4186, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4196, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4206, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4216, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4226, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4236, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4247, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4257, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4268, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4278, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4288, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4298, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4308, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4318, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4327, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4337, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4346, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4356, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4366, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4376, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4386, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4395, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4404, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4414, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4424, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4434, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4444, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4454, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4464, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4473, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4483, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4493, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4502, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4511, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4520, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4529, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4538, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4547, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4556, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4565, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4575, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4584, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4593, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4602, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4612, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4621, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4631, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4640, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4650, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4660, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4670, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4680, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4689, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4699, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4709, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4719, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4728, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4738, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4748, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4757, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4766, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4776, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4785, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4795, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4806, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4816, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4826, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4837, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4847, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4857, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4867, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4876, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4886, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4895, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4904, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4913, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4922, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4931, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4940, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4949, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4959, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4969, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4980, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.4990, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5000, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5010, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5020, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5030, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5040, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5050, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5060, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5070, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5080, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5090, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5101, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5111, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5121, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5131, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5141, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5152, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5162, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5172, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5182, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5191, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5201, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5211, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5221, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5231, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5241, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5250, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5260, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5270, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5280, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5290, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5300, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5310, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5319, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5330, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5340, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5350, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5360, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5370, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5380, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5390, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5400, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5410, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5419, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5429, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5439, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5448, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5457, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5466, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5476, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5486, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5496, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5505, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5515, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5524, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5534, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5543, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5553, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5562, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5573, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5583, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5593, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5603, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5614, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5624, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5634, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5644, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5654, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5664, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5674, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5683, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5693, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5702, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5710, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5720, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5729, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5738, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5747, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5757, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5768, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5778, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5788, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5798, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5808, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5818, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5828, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5838, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5849, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5860, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5870, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5880, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5890, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5901, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5911, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5922, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5932, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5942, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5953, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5963, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5973, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5983, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.5993, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6002, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6012, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6021, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6031, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6040, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6049, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6058, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6068, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6077, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6087, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6097, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6107, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6117, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6128, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6138, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6149, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6159, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6169, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6179, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6189, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6199, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6209, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6219, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6229, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6240, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6250, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6261, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6271, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6281, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6291, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6302, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6312, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6323, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6333, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6343, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6354, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6364, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6375, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6385, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6395, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6406, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6416, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6426, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6435, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6446, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6456, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6467, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6477, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6488, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6498, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6508, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6517, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6527, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6537, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6547, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6557, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6566, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6576, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6586, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6597, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6606, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6616, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6626, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6635, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6644, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6654, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6663, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6673, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6683, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6693, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6704, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6714, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6723, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6734, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6744, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6755, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6765, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6776, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6786, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6797, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6809, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6820, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6832, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6843, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6854, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6865, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6876, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6887, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6898, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6908, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6919, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6930, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6940, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6950, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6961, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6971, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6982, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.6992, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7003, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7013, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7023, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7033, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7043, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7054, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7063, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7073, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7083, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7093, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7104, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7114, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7124, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7134, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7143, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7153, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7163, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7174, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7185, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7195, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7206, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7217, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7228, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7239, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7250, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7261, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7271, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7281, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7291, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7300, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7310, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7320, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7330, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7340, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7351, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7361, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7370, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7381, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7391, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7402, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7413, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7423, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7434, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7445, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7456, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7467, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7478, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7489, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7500, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7511, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7521, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7532, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7543, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7553, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7564, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7575, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7586, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7597, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7608, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7619, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7630, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7642, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7653, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7664, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7675, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7687, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7698, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7709, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7721, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7732, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7744, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7755, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7767, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7778, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7788, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7799, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7810, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7821, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7831, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7841, device='cuda:0', requires_grad=True)
# INFO:root:scaling by Parameter containing:
# tensor(-1.7852, device='cuda:0', requires_grad=True)
# ...
# /rds/bear-apps/2022a/EL8-ice/software/PyTorch-Lightning/2.1.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/pytorch_lightning/trainer/call.py:54: Detected KeyboardInterrupt, attempting graceful shutdown...
# INFO:root:Re-loading from best cached checkpoint /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-time_test.ckpt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In [9], line 46
#      45 wandb.finish()
# ---> 46 experiment, dm = run(cfg)
#      47 print(f"Loaded model with {sum(p.numel() for p in experiment.model.parameters())/1e6} M parameters")
#
# File /rds/bear-apps/2022a/EL8-ice/software/Hydra/1.3.2-GCCcore-11.3.0/lib/python3.10/site-packages/hydra/main.py:83, in main.<locals>.main_decorator.<locals>.decorated_main(cfg_passthrough)
#      82 if cfg_passthrough is not None:
# ---> 83     return task_function(cfg_passthrough)
#      84 else:
#
# File ~/Projects/CPRD/examples/modelling/SurvStreamGPT/run_experiment.py:238, in run(cfg)
#     237     logging.info(f"Re-loading from best cached checkpoint {new_checkpoint}")
# --> 238     experiment_instance = Experiment.load_from_checkpoint(new_checkpoint)
#     240 # Test model
#
# File /rds/bear-apps/2022a/EL8-ice/software/PyTorch-Lightning/2.1.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/pytorch_lightning/utilities/model_helpers.py:91, in _restricted_classmethod_impl.__get__(self, instance, cls)
#      89 def __get__(self, instance: Optional[_T], cls: Type[_T]) -> Callable[_P, _R_co]:
#      90     # Workaround for https://github.com/pytorch/pytorch/issues/67146
# ---> 91     is_scripting = any(os.path.join("torch", "jit") in frameinfo.filename for frameinfo in inspect.stack())
#      92     if instance is not None and not is_scripting:
#
# File /rds/bear-apps/2022a/EL8-ice/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/inspect.py:1678, in stack(context)
#    1677 """Return a list of records for the stack above the caller's frame."""
# -> 1678 return getouterframes(sys._getframe(1), context)
#
# File /rds/bear-apps/2022a/EL8-ice/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/inspect.py:1655, in getouterframes(frame, context)
#    1654 while frame:
# -> 1655     frameinfo = (frame,) + getframeinfo(frame, context)
#    1656     framelist.append(FrameInfo(*frameinfo))
#
# File /rds/bear-apps/2022a/EL8-ice/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/inspect.py:1625, in getframeinfo(frame, context)
#    1623     raise TypeError('{!r} is not a frame or traceback object'.format(frame))
# -> 1625 filename = getsourcefile(frame) or getfile(frame)
#    1626 if context > 0:
#
# File /rds/bear-apps/2022a/EL8-ice/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/inspect.py:826, in getsourcefile(object)
#     825     return None
# --> 826 if os.path.exists(filename):
#     827     return filename
#
# File /rds/bear-apps/2022a/EL8-ice/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/genericpath.py:19, in exists(path)
#      18 try:
# ---> 19     os.stat(path)
#      20 except (OSError, ValueError):
#
# File /rds/bear-apps/2022a/EL8-ice/software/PyTorch/2.0.1-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py:66, in _set_SIGCHLD_handler.<locals>.handler(signum, frame)
#      63 def handler(signum, frame):
#      64     # This following call uses `waitid` with WNOHANG from C side. Therefore,
#      65     # Python can still get and update the process status successfully.
# ---> 66     _error_if_any_worker_fails()
#      67     if previous_handler is not None:
#
# SystemError: <built-in function _error_if_any_worker_fails> returned a result with an exception set
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File /rds/bear-apps/2022a/EL8-ice/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/IPython/core/interactiveshell.py:1997, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    1996     else:
# -> 1997         stb = self.InteractiveTB.structured_traceback(
#    1998             etype, value, tb, tb_offset=tb_offset
#    1999         )
#    2001 except Exception:
#
# File /rds/bear-apps/2022a/EL8-ice/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/IPython/core/ultratb.py:1112, in AutoFormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1111     self.tb = tb
# -> 1112 return FormattedTB.structured_traceback(
#    1113     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#
# File /rds/bear-apps/2022a/EL8-ice/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/IPython/core/ultratb.py:1006, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1004 if mode in self.verbose_modes:
#    1005     # Verbose modes need a full traceback
# -> 1006     return VerboseTB.structured_traceback(
#    1007         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1008     )
#    1009 elif mode == 'Minimal':
#
# File /rds/bear-apps/2022a/EL8-ice/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/IPython/core/ultratb.py:859, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#     858 """Return a nice text document describing the traceback."""
# --> 859 formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#     860                                                        tb_offset)
#     862 colors = self.Colors  # just a shorthand + quicker name lookup
#
# File /rds/bear-apps/2022a/EL8-ice/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/IPython/core/ultratb.py:793, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#     791 head = self.prepare_header(etype, self.long_header)
#     792 records = (
# --> 793     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     794 )
#     796 frames = []
#
# File /rds/bear-apps/2022a/EL8-ice/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/IPython/core/ultratb.py:848, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#     843 options = stack_data.Options(
#     844     before=before,
#     845     after=after,
#     846     pygments_formatter=formatter,
#     847 )
# --> 848 return list(stack_data.FrameInfo.stack_data(etb, options=options))[tb_offset:]
#
# File /rds/bear-apps/2022a/EL8-ice/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/stack_data/core.py:597, in FrameInfo.stack_data(cls, frame_or_tb, options, collapse_repeated_frames)
#     595     return frame.f_code, lineno
# --> 597 yield from collapse_repeated(
#     598     stack,
#     599     mapper=mapper,
#     600     collapser=RepeatedFrames,
#     601     key=_frame_key,
#     602 )
#
# File /rds/bear-apps/2022a/EL8-ice/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/stack_data/utils.py:84, in collapse_repeated(lst, collapser, mapper, key)
#      83 if is_highlighted:
# ---> 84     yield from map(mapper, original_group)
#      85 else:
#
# File /rds/bear-apps/2022a/EL8-ice/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/stack_data/core.py:587, in FrameInfo.stack_data.<locals>.mapper(f)
#     586 def mapper(f):
# --> 587     return cls(f, options)
#
# File /rds/bear-apps/2022a/EL8-ice/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/stack_data/core.py:551, in FrameInfo.__init__(self, frame_or_tb, options)
#     546 def __init__(
#     547         self,
#     548         frame_or_tb: Union[FrameType, TracebackType],
#     549         options: Optional[Options] = None,
#     550 ):
# --> 551     self.executing = Source.executing(frame_or_tb)
#     552     frame, self.lineno = frame_and_lineno(frame_or_tb)
#
# File /rds/bear-apps/2022a/EL8-ice/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/executing/executing.py:323, in Source.executing(cls, frame_or_tb)
#     322 node = stmts = decorator = None
# --> 323 source = cls.for_frame(frame)
#     324 tree = source.tree
#
# File /rds/bear-apps/2022a/EL8-ice/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/executing/executing.py:247, in Source.for_frame(cls, frame, use_cache)
#     244 """
#     245 Returns the `Source` object corresponding to the file the frame is executing in.
#     246 """
# --> 247 return cls.for_filename(frame.f_code.co_filename, frame.f_globals or {}, use_cache)
#
# File /rds/bear-apps/2022a/EL8-ice/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/executing/executing.py:275, in Source.for_filename(cls, filename, module_globals, use_cache)
#     274 lines = tuple(lines)
# --> 275 return cls._for_filename_and_lines(filename, lines)
#
# File /rds/bear-apps/2022a/EL8-ice/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/executing/executing.py:285, in Source._for_filename_and_lines(cls, filename, lines)
#     283     pass
# --> 285 result = source_cache[(filename, lines)] = cls(filename, lines)
#     286 return result
#
# File /rds/bear-apps/2022a/EL8-ice/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/stack_data/core.py:97, in Source.__init__(self, *args, **kwargs)
#      96 if self.tree:
# ---> 97     self.asttokens()
#
# File /rds/bear-apps/2022a/EL8-ice/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/executing/executing.py:387, in Source.asttokens(self)
#     386 from asttokens import ASTTokens  # must be installed separately
# --> 387 return ASTTokens(
#     388     self.text,
#     389     tree=self.tree,
#     390     filename=self.filename,
#     391 )
#
# File /rds/bear-apps/2022a/EL8-ice/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/asttokens/asttokens.py:67, in ASTTokens.__init__(self, source_text, parse, tree, filename)
#      66 # Tokenize the code.
# ---> 67 self._tokens = list(self._generate_tokens(source_text))
#      69 # Extract the start positions of all tokens, so that we can quickly map positions to tokens.
#
# File /rds/bear-apps/2022a/EL8-ice/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/asttokens/asttokens.py:102, in ASTTokens._generate_tokens(self, text)
#      99 tok_type, tok_str, start, end, line = tok
#     100 yield Token(tok_type, tok_str, start, end, line, index,
#     101             self._line_numbers.line_to_offset(start[0], start[1]),
# --> 102             self._line_numbers.line_to_offset(end[0], end[1]))
#
# File /rds/bear-apps/2022a/EL8-ice/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/asttokens/line_numbers.py:64, in LineNumbers.line_to_offset(self, line, column)
#      63 else:
# ---> 64   return min(self._line_offsets[line] + max(0, column), self._text_len)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File /rds/bear-apps/2022a/EL8-ice/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2018, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2015         self._showtraceback(etype, value, stb)
#    2017 except KeyboardInterrupt:
# -> 2018     print('\n' + self.get_exception_only(), file=sys.stderr)
#
# File /rds/bear-apps/2022a/EL8-ice/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/IPython/core/interactiveshell.py:1954, in InteractiveShell.get_exception_only(self, exc_tuple)
#    1949 """
#    1950 Return as a string (ending with a newline) the exception that
#    1951 just occurred, without any traceback.
#    1952 """
#    1953 etype, value, tb = self._get_exc_info(exc_tuple)
# -> 1954 msg = traceback.format_exception_only(etype, value)
#    1955 return ''.join(msg)
#
# File /rds/bear-apps/2022a/EL8-ice/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/traceback.py:155, in format_exception_only(exc, value)
#     153 if value is _sentinel:
#     154     value = exc
# --> 155 te = TracebackException(type(value), value, None, compact=True)
#     156 return list(te.format_exception_only())
#
# File /rds/bear-apps/2022a/EL8-ice/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/traceback.py:552, in TracebackException.__init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, compact, _seen)
#     549     need_context = True
#     550 if (e and e.__context__ is not None
#     551     and need_context and id(e.__context__) not in _seen):
# --> 552     context = TracebackException(
#     553         type(e.__context__),
#     554         e.__context__,
#     555         e.__context__.__traceback__,
#     556         limit=limit,
#     557         lookup_lines=lookup_lines,
#     558         capture_locals=capture_locals,
#     559         _seen=_seen)
#     560 else:
#     561     context = None
#
# File /rds/bear-apps/2022a/EL8-ice/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/traceback.py:502, in TracebackException.__init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, compact, _seen)
#     499 _seen.add(id(exc_value))
#     501 # TODO: locals.
# --> 502 self.stack = StackSummary.extract(
#     503     walk_tb(exc_traceback), limit=limit, lookup_lines=lookup_lines,
#     504     capture_locals=capture_locals)
#     505 self.exc_type = exc_type
#     506 # Capture now to permit freeing resources: only complication is in the
#     507 # unofficial API _format_final_exc_line
#
# File /rds/bear-apps/2022a/EL8-ice/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/traceback.py:379, in StackSummary.extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     376     result.append(FrameSummary(
#     377         filename, lineno, name, lookup_line=False, locals=f_locals))
#     378 for filename in fnames:
# --> 379     linecache.checkcache(filename)
#     380 # If immediate lookup was desired, trigger lookups now.
#     381 if lookup_lines:
#
# File /rds/bear-apps/2022a/EL8-ice/software/IPython/8.5.0-GCCcore-11.3.0/lib/python3.10/site-packages/IPython/core/compilerop.py:193, in check_linecache_ipython(*args)
#     190 """Call linecache.checkcache() safely protecting our cached values.
#     191 """
#     192 # First call the original checkcache as intended
# --> 193 linecache._checkcache_ori(*args)
#     194 # Then, update back the cache with our data, so that tracebacks related
#     195 # to our compiled codes can be produced.
#     196 linecache.cache.update(linecache._ipython_cache)
#
# File /rds/bear-apps/2022a/EL8-ice/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/linecache.py:72, in checkcache(filename)
#      70     continue   # no-op for files loaded via a __loader__
#      71 try:
# ---> 72     stat = os.stat(fullname)
#      73 except OSError:
#      74     cache.pop(filename, None)
#
# File /rds/bear-apps/2022a/EL8-ice/software/PyTorch/2.0.1-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py:66, in _set_SIGCHLD_handler.<locals>.handler(signum, frame)
#      63 def handler(signum, frame):
#      64     # This following call uses `waitid` with WNOHANG from C side. Therefore,
#      65     # Python can still get and update the process status successfully.
# ---> 66     _error_if_any_worker_fails()
#      67     if previous_handler is not None:
#      68         assert callable(previous_handler)
#
# SystemError: <built-in function _error_if_any_worker_fails> returned a result with an exception set

# %% [markdown]
# Subsets of data

# %%
pre_trained_models = ["CR_11M_24_11_01_big_posencscale_", "NULL"]
experiments = ["hypertension", "cvd"] 

for pre_trained_model in pre_trained_models:

    for experiment in experiments:
    
        # load the configuration file, override any settings 
        with initialize(version_base=None, config_path="../../../confs", job_name="testing_notebook"):
            cfg = compose(config_name="config_CompetingRisk37M", 
                          overrides=[# Experiment setup
                                     "experiment.type='few-shot'",
                                     f"experiment.run_id='{pre_trained_model}'",
                                     f"experiment.fine_tune_id='{experiment}-few-shot-cr3'",
                                     "experiment.train=True",
                                     "experiment.test=True",
                                     # Dataloader
                                     "data.meta_information_path=/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle",
                                     "data.min_workers=12",
                                     "data.subsample_training=600",
                                     # Optimiser
                                     "optim.num_epochs=50",
                                     "optim.limit_test_batches=null",
                                     "optim.scheduler=ReduceOnPlateau",
                                     "optim.scheduler_warmup=False",
                                     # "optim.scheduler_periods=250",
                                     "optim.learning_rate=1e-3",
                                     "optim.val_check_interval=5",
                                     "optim.early_stop=True",
                                     "optim.early_stop_patience=20",
                                     # Head
                                     "head.surv_weight=1",
                                     "head.value_weight=0",
                                    ]
                         )     
    
        
        match experiment.lower():
            case "cvd":
                cfg.data.path_to_ds="/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/"
                cfg.experiment.fine_tune_outcomes=["IHDINCLUDINGMI_OPTIMALV2", "ISCHAEMICSTROKE_V2", "MINFARCTION", "STROKEUNSPECIFIED_V2", "STROKE_HAEMRGIC"]
            case "hypertension":
                cfg.data.path_to_ds="/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_Hypertension/"
                cfg.experiment.fine_tune_outcomes=["HYPERTENSION"]
                
        wandb.finish()
        experiment, dm = run(cfg)
        print(f"Loaded model with {sum(p.numel() for p in experiment.model.parameters())/1e6} M parameters")
        wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.008 MB of 0.031 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.265035…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Scheduler</td><td>▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Val:OutcomePerformanceMetricsctd</td><td>▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▆▆▆▆▆▇▇▇██▇▇█</td></tr><tr><td>Val:OutcomePerformanceMetricsibs</td><td>████▇▇▇▅▅▄▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▂▂▁▁▁▁▁▁</td></tr><tr><td>Val:OutcomePerformanceMetricsinbll</td><td>█▇▆▅▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▄▃▃▂▃▂▃▁▂▂</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>val_loss</td><td>█▆▅▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Scheduler</td><td>0.001</td></tr><tr><td>Val:OutcomePerformanceMetricsctd</td><td>0.48775</td></tr><tr><td>Val:OutcomePerformanceMetricsibs</td><td>0.08782</td></tr><tr><td>Val:OutcomePerformanceMetricsinbll</td><td>0.33684</td></tr><tr><td>epoch</td><td>22</td></tr><tr><td>train_loss</td><td>1.63691</td></tr><tr><td>trainer/global_step</td><td>229</td></tr><tr><td>val_loss</td><td>2.57015</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr2</strong>: <a href="https://wandb.ai/cwlgadd/SurvivEHR/runs/1558yhrr" target="_blank">https://wandb.ai/cwlgadd/SurvivEHR/runs/1558yhrr</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/wandb/run-20241116_154045-1558yhrr/logs</code>
# INFO:root:Running cr on 72 CPUs and 1 GPUs
# INFO:root:====================================================================================================
# INFO:root:# Loading DataModule for dataset /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_Hypertension/. This will be loaded in supervised form.
# INFO:root:====================================================================================================
# INFO:root:Creating supervised collator for DataModule
# INFO:root:Using meta information from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle
# INFO:root:Using train file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_Hypertension/file_row_count_dict_train.pickle
# INFO:root:Using test file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_Hypertension/file_row_count_dict_test.pickle
# INFO:root:Using val file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_Hypertension/file_row_count_dict_val.pickle
# INFO:root:Tokenzier created based on 7,555,415,275 tokens
# INFO:root:Using tabular tokenizer, created from meta information and containing 265 tokens
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_Hypertension/split=train/ dataset, with 600 subsamples
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_Hypertension/split=test/ dataset, with 35,758 samples
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_Hypertension/split=val/ dataset, with 33,280 samples
# INFO:root:is_decoder: true
# data:
#   batch_size: 64
#   unk_freq_threshold: 0.0
#   min_workers: 12
#   global_diagnoses: false
#   path_to_db: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/
#   path_to_ds: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_Hypertension/
#   meta_information_path: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle
#   subsample_training: 600
# experiment:
#   type: few-shot
#   project_name: SurvivEHR
#   run_id: CR_11M_24_11_01_big_posencscale_
#   fine_tune_id: hypertension-few-shot-cr3
#   train: true
#   test: true
#   verbose: true
#   seed: 1337
#   log: true
#   log_dir: /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/
#   ckpt_dir: /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/
#   fine_tune_outcomes:
#   - HYPERTENSION
# optim:
#   num_epochs: 50
#   learning_rate: 0.0003
#   scheduler_warmup: false
#   scheduler: ReduceOnPlateau
#   scheduler_periods: 10000
#   learning_rate_decay: 0.8
#   val_check_interval: 5
#   early_stop: true
#   early_stop_patience: 20
#   log_every_n_steps: 20
#   limit_val_batches: 0.025
#   limit_test_batches: null
# transformer:
#   block_type: Neo
#   block_size: 256
#   n_layer: 10
#   n_head: 8
#   n_embd: 1024
#   layer_norm_bias: false
#   attention_type: global
#   bias: true
#   dropout: 0.0
#   attention_dropout: 0.0
#   resid_dropout: 0.0
#   private_heads: 0
# head:
#   SurvLayer: cr
#   surv_weight: 1
#   tokens_for_univariate_regression:
#   - 84
#   - 86
#   - 107
#   - 154
#   - 42
#   - 231
#   - 63
#   - 85
#   - 247
#   - 51
#   - 103
#   - 146
#   - 66
#   - 172
#   - 152
#   - 261
#   - 235
#   - 193
#   - 184
#   - 101
#   - 223
#   - 135
#   - 226
#   - 202
#   - 145
#   - 244
#   - 165
#   - 64
#   - 185
#   - 238
#   - 220
#   - 232
#   - 240
#   - 237
#   - 17
#   - 239
#   - 217
#   - 118
#   - 219
#   - 251
#   - 25
#   - 150
#   - 111
#   - 102
#   - 15
#   - 110
#   - 130
#   - 128
#   - 122
#   - 99
#   - 77
#   - 96
#   - 140
#   - 50
#   - 80
#   - 108
#   - 138
#   - 27
#   - 139
#   - 125
#   - 117
#   - 105
#   - 109
#   - 243
#   - 236
#   - 208
#   - 98
#   - 176
#   - 209
#   - 194
#   - 61
#   - 73
#   - 214
#   - 206
#   - 229
#   - 225
#   - 183
#   - 186
#   - 215
#   - 187
#   - 248
#   - 179
#   - 163
#   - 180
#   - 181
#   - 153
#   - 245
#   - 54
#   - 246
#   - 112
#   - 212
#   - 141
#   - 204
#   - 227
#   - 173
#   - 55
#   - 119
#   - 262
#   - 127
#   - 71
#   - 59
#   - 144
#   - 113
#   - 170
#   - 241
#   - 168
#   - 47
#   - 159
#   value_weight: 0
#
# INFO:root:====================================================================================================
# INFO:root:# Few-shot learning experiment.
# INFO:root:====================================================================================================
# INFO:root:Creating new few-shot model at the path /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt. This is initialised from a pre-trained causal model, which can be found at checkpoint /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale_.ckpt.
# INFO:root:Running few-shot experiment with outcomes {'HYPERTENSION': 129}
# INFO:root:Loading from checkpoint
# INFO:root:Using Temporal Positional Encoding. This module uses the patient's age at an event within their time series.
# INFO:root:Using Competing-Risk DeSurv head.
# INFO:root:In generation forwarding DeSurv on the grid between [0.0, 1.0] with 1000 intervals
# INFO:root:Fixing Transformer parameters and training only head.
# INFO:root:Re-initialising survival head weights
# INFO:root:Re-initialising survival head parameters.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# INFO:root:Training model.
# wandb version 0.18.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.6
# Run data is saved locally in <code>/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/wandb/run-20241116_155211-wiqgjjrw</code>
# Syncing run <strong><a href="https://wandb.ai/cwlgadd/SurvivEHR/runs/wiqgjjrw" target="_blank">CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3</a></strong> to <a href="https://wandb.ai/cwlgadd/SurvivEHR" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# /rds/bear-apps/2022a/EL8-ice/software/PyTorch-Lightning/2.1.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:630: Checkpoint directory /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:root:Using ReduceLROnPlateau scheduler
# INFO:root:Not using warm-up in scheduler
#
#   | Name  | Type                            | Params
# ----------------------------------------------------------
# 0 | model | SurvStreamGPTForCausalModelling | 129 M
# ----------------------------------------------------------
# 541 K     Trainable params
# 128 M     Non-trainable params
# 129 M     Total params
# 517.425   Total estimated model params size (MB)
# SLURM auto-requeueing enabled. Setting signal handlers.
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /rds/bear-apps/2022a/EL8-ice/software/PyTorch-Lightning/2.1.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:293: The number of training batches (10) is smaller than the logging interval Trainer(log_every_n_steps=20). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved. New best score: 6.577
# Epoch 0, global step 5: 'val_loss' reached 6.57685 (best 6.57685), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.280 >= min_delta = 0. New best score: 6.297
# Epoch 0, global step 10: 'val_loss' reached 6.29693 (best 6.29693), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.269 >= min_delta = 0. New best score: 6.028
# Epoch 1, global step 15: 'val_loss' reached 6.02756 (best 6.02756), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.259 >= min_delta = 0. New best score: 5.768
# Epoch 1, global step 20: 'val_loss' reached 5.76816 (best 5.76816), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.245 >= min_delta = 0. New best score: 5.524
# Epoch 2, global step 25: 'val_loss' reached 5.52360 (best 5.52360), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.234 >= min_delta = 0. New best score: 5.290
# Epoch 2, global step 30: 'val_loss' reached 5.28986 (best 5.28986), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.220 >= min_delta = 0. New best score: 5.070
# Epoch 3, global step 35: 'val_loss' reached 5.07036 (best 5.07036), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.206 >= min_delta = 0. New best score: 4.864
# Epoch 3, global step 40: 'val_loss' reached 4.86434 (best 4.86434), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.192 >= min_delta = 0. New best score: 4.673
# Epoch 4, global step 45: 'val_loss' reached 4.67256 (best 4.67256), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.176 >= min_delta = 0. New best score: 4.496
# Epoch 4, global step 50: 'val_loss' reached 4.49622 (best 4.49622), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.161 >= min_delta = 0. New best score: 4.335
# Epoch 5, global step 55: 'val_loss' reached 4.33534 (best 4.33534), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.146 >= min_delta = 0. New best score: 4.190
# Epoch 5, global step 60: 'val_loss' reached 4.18951 (best 4.18951), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.134 >= min_delta = 0. New best score: 4.056
# Epoch 6, global step 65: 'val_loss' reached 4.05554 (best 4.05554), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.121 >= min_delta = 0. New best score: 3.935
# Epoch 6, global step 70: 'val_loss' reached 3.93478 (best 3.93478), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.108 >= min_delta = 0. New best score: 3.827
# Epoch 7, global step 75: 'val_loss' reached 3.82714 (best 3.82714), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.097 >= min_delta = 0. New best score: 3.730
# Epoch 7, global step 80: 'val_loss' reached 3.72968 (best 3.72968), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.088 >= min_delta = 0. New best score: 3.641
# Epoch 8, global step 85: 'val_loss' reached 3.64122 (best 3.64122), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.080 >= min_delta = 0. New best score: 3.561
# Epoch 8, global step 90: 'val_loss' reached 3.56122 (best 3.56122), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.074 >= min_delta = 0. New best score: 3.487
# Epoch 9, global step 95: 'val_loss' reached 3.48682 (best 3.48682), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.067 >= min_delta = 0. New best score: 3.420
# Epoch 9, global step 100: 'val_loss' reached 3.41991 (best 3.41991), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.060 >= min_delta = 0. New best score: 3.360
# Epoch 10, global step 105: 'val_loss' reached 3.36039 (best 3.36039), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.054 >= min_delta = 0. New best score: 3.307
# Epoch 10, global step 110: 'val_loss' reached 3.30663 (best 3.30663), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.049 >= min_delta = 0. New best score: 3.258
# Epoch 11, global step 115: 'val_loss' reached 3.25784 (best 3.25784), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.046 >= min_delta = 0. New best score: 3.212
# Epoch 11, global step 120: 'val_loss' reached 3.21217 (best 3.21217), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.040 >= min_delta = 0. New best score: 3.172
# Epoch 12, global step 125: 'val_loss' reached 3.17174 (best 3.17174), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.037 >= min_delta = 0. New best score: 3.134
# Epoch 12, global step 130: 'val_loss' reached 3.13436 (best 3.13436), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.035 >= min_delta = 0. New best score: 3.100
# Epoch 13, global step 135: 'val_loss' reached 3.09974 (best 3.09974), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.032 >= min_delta = 0. New best score: 3.068
# Epoch 13, global step 140: 'val_loss' reached 3.06788 (best 3.06788), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.029 >= min_delta = 0. New best score: 3.039
# Epoch 14, global step 145: 'val_loss' reached 3.03913 (best 3.03913), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.027 >= min_delta = 0. New best score: 3.013
# Epoch 14, global step 150: 'val_loss' reached 3.01253 (best 3.01253), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.026 >= min_delta = 0. New best score: 2.987
# Epoch 15, global step 155: 'val_loss' reached 2.98654 (best 2.98654), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.023 >= min_delta = 0. New best score: 2.964
# Epoch 15, global step 160: 'val_loss' reached 2.96354 (best 2.96354), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.021 >= min_delta = 0. New best score: 2.942
# Epoch 16, global step 165: 'val_loss' reached 2.94242 (best 2.94242), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.020 >= min_delta = 0. New best score: 2.923
# Epoch 16, global step 170: 'val_loss' reached 2.92282 (best 2.92282), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.018 >= min_delta = 0. New best score: 2.905
# Epoch 17, global step 175: 'val_loss' reached 2.90526 (best 2.90526), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.017 >= min_delta = 0. New best score: 2.888
# Epoch 17, global step 180: 'val_loss' reached 2.88807 (best 2.88807), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.014 >= min_delta = 0. New best score: 2.874
# Epoch 18, global step 185: 'val_loss' reached 2.87371 (best 2.87371), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.015 >= min_delta = 0. New best score: 2.859
# Epoch 18, global step 190: 'val_loss' reached 2.85861 (best 2.85861), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.014 >= min_delta = 0. New best score: 2.845
# Epoch 19, global step 195: 'val_loss' reached 2.84503 (best 2.84503), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.013 >= min_delta = 0. New best score: 2.832
# Epoch 19, global step 200: 'val_loss' reached 2.83174 (best 2.83174), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.012 >= min_delta = 0. New best score: 2.819
# Epoch 20, global step 205: 'val_loss' reached 2.81933 (best 2.81933), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.012 >= min_delta = 0. New best score: 2.807
# Epoch 20, global step 210: 'val_loss' reached 2.80747 (best 2.80747), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.014 >= min_delta = 0. New best score: 2.794
# Epoch 21, global step 215: 'val_loss' reached 2.79381 (best 2.79381), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.011 >= min_delta = 0. New best score: 2.783
# Epoch 21, global step 220: 'val_loss' reached 2.78256 (best 2.78256), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.008 >= min_delta = 0. New best score: 2.775
# Epoch 22, global step 225: 'val_loss' reached 2.77457 (best 2.77457), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.009 >= min_delta = 0. New best score: 2.766
# Epoch 22, global step 230: 'val_loss' reached 2.76572 (best 2.76572), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.010 >= min_delta = 0. New best score: 2.756
# Epoch 23, global step 235: 'val_loss' reached 2.75600 (best 2.75600), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.008 >= min_delta = 0. New best score: 2.748
# Epoch 23, global step 240: 'val_loss' reached 2.74786 (best 2.74786), saving model to '/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# /rds/bear-apps/2022a/EL8-ice/software/PyTorch-Lightning/2.1.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/pytorch_lightning/trainer/call.py:54: Detected KeyboardInterrupt, attempting graceful shutdown...
# INFO:root:Re-loading from best cached checkpoint /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CR_11M_24_11_01_big_posencscale__hypertension-few-shot-cr3.ckpt
#
# KeyboardInterrupt
#
# wandb: Network error (ReadTimeout), entering retry loop.

# %%
for batch in dm.train_dataloader():
    break

# %%
# dm.train_set.view_sample(1, max_dynamic_events=4)

display(batch["tokens"][0, :])
display(batch["target_token"][0])

experiment.forward(batch)

# %%
dm.encode(cfg.experiment.fine_tune_outcomes)
display(dm.decode([0]))
display(len(list(dm.train_set.tokenizer._event_counts["EVENT"])))

# %%
# import wandb
print(model)
# wandb.finish()

# %%
dm.encode(['IHDINCLUDINGMI_OPTIMALV2', 'ISCHAEMICSTROKE_V2', 'MINFARCTION', 'STROKEUNSPECIFIED_V2', 'STROKE_HAEMRGIC'])
# display(dm.decode([95, 175, 263,249]).split(" "))

# %%
dm.tokenizer._event_counts["EVENT"][-5:].to_list()

# %%
save_path = f"/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/{cfg.experiment.run_id}/"

# %% [markdown]
# # Load Pre-Trained model

# %%
ckpt_path = cfg.experiment.log_dir + f'checkpoints/{cfg.experiment.run_id}.ckpt'
model = SurvivalExperiment.load_from_checkpoint(ckpt_path)

# %% [markdown]
# # Initialise fine-tuning data module

# %%
# Update dataset path to point to the new dataset 
cfg.data.path_to_ds = "/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/"

# Build 
dm = FoundationalDataModule(path_to_db=cfg.data.path_to_db,
                            path_to_ds=cfg.data.path_to_ds,
                            load=True,
                            tokenizer="tabular",
                            batch_size=cfg.data.batch_size,
                            max_seq_length=cfg.transformer.block_size,
                            freq_threshold=cfg.data.unk_freq_threshold,
                            min_workers=cfg.data.min_workers,
                            overwrite_meta_information=cfg.data.meta_information_path,
                           )

vocab_size = dm.train_set.tokenizer.vocab_size
print(f"{vocab_size} vocab elements")

# list of univariate measurements to model with Normal distribution
# Extract the measurements, using the fact that the diagnoses are all up upper case.
measurements_for_univariate_regression = [record for record in dm.tokenizer._event_counts["EVENT"] if record.upper() != record]
cfg.head.tokens_for_univariate_regression = dm.encode(measurements_for_univariate_regression) 
# display(measurements_for_univariate_regression)

# %%
# # import pickle as pkl
# # import pathlib

# pkl_file_to_amend = "/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/file_row_count_dict_test.pickle"

# with open(pkl_file_to_amend, 'rb') as pickle_file:
#     content = pickle.load(pickle_file)
# display(content)

# # new_dictionary = {}
# # for key in content.keys():
# #     str_to_remove = "/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/FineTune_CVD/split=val/"
# #     new_key = str(key)[len(str_to_remove):]
# #     new_dictionary[new_key] = content[key]
# # display(new_dictionary)


# # with open(pkl_file_to_amend, 'wb') as handle:
# #     pickle.dump(new_dictionary, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# new_dictionary

# %%
import copy
start = time.time()   # starting time
for batch in dm.train_dataloader():
    # print(batch["tokens"][1,:])
    
    c_batch = convert_batch_to_none_causal(batch)
    # print(c_batch["tokens"][1,:])
    # print(c_batch["target_token"][1])

    # print(batch["tokens"][1,:])
    
    break
    
print(f"batch loaded in {time.time()-start} seconds")    
    
# for key in batch.keys():
#     print(f"{key}".ljust(20) + f"{batch[key].shape}")

# tokens = batch["tokens"][0].tolist()    
# sentence = dm.decode(tokens).split(" ")
# for token, value in zip(sentence, batch["values"][0].tolist()):
#     print(f"{token}:".ljust(40) + f"{value}")

# %%
display(batch.keys())
display(c_batch.keys())

print(batch["static_covariates"].shape)

# print(dm.train_set.static_1hot)
# print(dm.train_set.static_1hot["SEX"].categories_)
# print(dm.train_set.static_1hot["IMD"].categories_)
# print(dm.train_set.static_1hot["ETHNICITY"].categories_)

print(batch["tokens"][1,:])
print(c_batch["tokens"][1,:])
print(c_batch["target_token"][1])

# %% [markdown]
# ## View an example sample

# %%
dm.test_set.view_sample(11003, max_dynamic_events=None, report_time=True)

# %% [markdown]
# # Custom wrapper prediction last token
#
# To begin with, I will just loop over samples individually to test the zero-shot capacity of SurvivEHR.

# %%
# Verifying on datamodule 
for _idx, batch in enumerate(dm.test_dataloader()):
    if _idx > 10:
        break
    print(_idx)
    print(torch.stack([batch["tokens"][10,:5], 
                       batch["values"][10,:5],  
                       batch["ages"][10,:5],
                       batch["attention_mask"][10,:5]]))
    batch = replace_last_non_pad_with_pad(batch)
    print(torch.stack([batch["tokens"][10,:5], 
                       batch["values"][10,:5],  
                       batch["ages"][10,:5],
                       batch["attention_mask"][10,:5]]))

# %%
outcome_of_interest = ["COPD", "SUBSTANCEMISUSE"]
outcome_token = dm.encode(outcome_of_interest)[0]
print(outcome_token)
# print(model(batch))

# %%
Hs, labels = [], []
mins,maxes=[],[]
for _idx, batch in enumerate(dm.test_dataloader()):

    batch = replace_last_non_pad_with_pad(batch)
    print(batch["tokens".shape)
    outputs, _, hidden_states = model(batch, is_generation=True)
    print(outputs)
    
    hidden_states = hidden_states.cpu().detach().numpy()                           # (64, 128, 384) 
    Hs.append( hidden_states.reshape(hidden_states.shape[0], -1) )
    labels.append((batch["target_token"] == outcome_token).long().numpy())

    if _idx == 9:
        break

# %% [markdown]
# # Visualise hidden dimension labelled by target

# %%
import umap
from sklearn.preprocessing import StandardScaler

H = np.concatenate(Hs, 0)
lbl = np.concatenate(labels, 0)

H = StandardScaler().fit_transform(H)
reducer = umap.UMAP()
H_proj = reducer.fit_transform(H)

plt.close()
plt.scatter(H_proj[:,0], H_proj[:,1], c=lbl)
plt.savefig(save_path + f"zero_shot/hidden_umap.png")

# %%
print(outputs["surv"]["surv_CDF"][outcome_token].shape)

# The first two tokens in the vocab correspond to the PAD and UNK tokens. There is no CDF corresponding to the PAD token, so the indexing for surv_CDF begins as ["UNK", "ADDISONS_DISEASE", ...]
# print(dm.decode([0,1,2]))

outcomes = ["COPD", "SUBSTANCEMISUSE"]
outcome_tokens = dm.encode(outcomes)

# for outcome in outcomes:
    # observed_outcome_token = dm.encode([outcome])[0]
cdf = np.zeros_like(outputs["surv"]["surv_CDF"][0])
lbls = np.zeros_like(batch["target_token"])

for _outcome_token in outcome_tokens:
    cdf += outputs["surv"]["surv_CDF"][_outcome_token - 1] 
    lbls += (batch["target_token"] == _outcome_token).long().numpy()

plt.close()
cdf_true = cdf[lbls==1,:]
cdf_false = cdf[lbls==0,:]
for i in range(cdf_true.shape[0]):
    plt.plot(np.linspace(1,1826,1826), cdf_true[i,:], c="r", label="outcome occurred next" if i == 0 else None, alpha=1)
for i in range(cdf_false.shape[0]):
    plt.plot(np.linspace(1,1826,1826), cdf_false[i,:], c="k", label="outcome did not occur next" if i == 0 else None, alpha=0.3)

plt.legend(loc=2)
plt.xlabel("days")
plt.ylabel(f"P(t>T) - outcomes={','.join(outcomes)}")
plt.savefig(save_path + f"zero_shot/cdf_outcomes.png")

# %%
print(batch["target_token"].unique())
print(len(outputs["surv"]["surv_CDF"]))

# %%
dm.decode([2])

# %%
outputs["surv"]["surv_CDF"][observed_outcome_token - 1]
