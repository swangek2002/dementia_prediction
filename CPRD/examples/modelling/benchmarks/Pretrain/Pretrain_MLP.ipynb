# %% [markdown]
# # Testing the pre-trained NN classifier for next event prediction
#
# This model uses a cross-sectional input

# %%
import os
from pathlib import Path
import sys
node_type = os.getenv('BB_CPU')
venv_dir = f'/rds/homes/g/gaddcz/Projects/CPRD/virtual-envTorch2.0-{node_type}'
venv_site_pkgs = Path(venv_dir) / 'lib' / f'python{sys.version_info.major}.{sys.version_info.minor}' / 'site-packages'
if venv_site_pkgs.exists():
    sys.path.insert(0, str(venv_site_pkgs))
    print(f"Added path '{venv_site_pkgs}' at start of search paths.")
else:
    print(f"Path '{venv_site_pkgs}' not found. Check that it exists and/or that it exists for node-type '{node_type}'.")

# %load_ext autoreload
# %autoreload 2

# %env SLURM_NTASKS_PER_NODE=28
# Out:
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
# Added path '/rds/homes/g/gaddcz/Projects/CPRD/virtual-envTorch2.0-icelake/lib/python3.10/site-packages' at start of search paths.
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# env: SLURM_NTASKS_PER_NODE=28

# %%
import torch
import logging
from hydra import compose, initialize

from setup_causal_mlp_experiment import CausalMLPExperiment, setup_mlp_experiment
from setup_causal_t_mlp_experiment import CausalTMLPExperiment, setup_t_mlp_experiment
from SurvivEHR.examples.modelling.benchmarks.Pretrain.run_experiment import run

torch.manual_seed(1337)
logging.basicConfig(level=logging.INFO)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# device = "cpu"    # if more informative debugging statements are needed
print(f"Using device: {device}.")

# %env SLURM_NTASKS_PER_NODE=28
# Out:
# Using device: cuda.
# env: SLURM_NTASKS_PER_NODE=28

# %% [markdown]
# # Create and run pre-trained experiment

# %%
with initialize(version_base=None, config_path="../../SurvivEHR/confs", job_name=""):
    cfg = compose(config_name="config_CompetingRisk11M", 
                  overrides=["experiment.run_id='CrossSectionalMLP'",
                             "data.meta_information_path=/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle",
                             "data.min_workers=12",
                             "experiment.train=False",
                             "experiment.test=True",
                             "experiment.log=False",
                             "+static=True"
                            ])

model, dm = run(cfg)
print(f"Loaded model with {sum(p.numel() for p in model.parameters())/1e6} M parameters")

wandb.finish()
# Out:
# INFO:root:Running cr on 72 CPUs and 1 GPUs
# INFO:root:====================================================================================================
# INFO:root:# Loading DataModule for dataset /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/. This will be loaded in causal form.
# INFO:root:====================================================================================================
# INFO:root:Creating unsupervised collator for DataModule
# INFO:root:Using meta information from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle
# INFO:root:Using train file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/file_row_count_dict_train.pickle
# INFO:root:Using test file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/file_row_count_dict_test.pickle
# INFO:root:Using val file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/file_row_count_dict_val.pickle
# INFO:root:Tokenzier created based on 7,555,415,275 tokens
# INFO:root:Using tabular tokenizer, created from meta information and containing 265 tokens
# INFO:root:Set seed to 1337
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/split=train/ dataset, with 23,613,894 samples
# INFO:root:Set seed to 42
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/split=test/ dataset, with 1,508,320 samples
# INFO:root:Set seed to 42
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/split=val/ dataset, with 1,426,714 samples
# INFO:root:is_decoder: true
# data:
#   batch_size: 64
#   unk_freq_threshold: 0.0
#   min_workers: 12
#   global_diagnoses: false
#   repeating_events: true
#   path_to_db: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/cprd.db
#   path_to_ds: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/
#   meta_information_path: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle
#   subsample_training: null
# experiment:
#   type: pre-train
#   project_name: SurvivEHR
#   run_id: CrossSectionalMLP
#   fine_tune_id: null
#   notes: null
#   tags: null
#   train: false
#   test: true
#   verbose: true
#   seed: 1337
#   log: false
#   log_dir: /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/
#   ckpt_dir: /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/
# fine_tuning:
#   fine_tune_outcomes: null
#   custom_outcome_method:
#     _target_: null
#   custom_stratification_method:
#     _target_: null
#   use_callbacks:
#     hidden_embedding: true
#     performance_metrics: true
#     rmst: false
#   head:
#     surv_weight: 1
#     value_weight: 0
#     learning_rate: 0.0005
# optim:
#   num_epochs: 1
#   learning_rate: 0.0003
#   scheduler_warmup: true
#   scheduler: decaycawarmrestarts
#   scheduler_periods: 10000
#   learning_rate_decay: 0.8
#   val_check_interval: 2500
#   early_stop: true
#   early_stop_patience: 30
#   log_every_n_steps: 20
#   limit_val_batches: 0.025
#   limit_test_batches: null
#   accumulate_grad_batches: 1
# transformer:
#   block_type: Neo
#   block_size: 256
#   n_layer: 6
#   n_head: 6
#   n_embd: 384
#   layer_norm_bias: false
#   attention_type: global
#   bias: true
#   dropout: 0.0
#   attention_dropout: 0.0
#   resid_dropout: 0.0
#   private_heads: 0
#   use_fine_tune_adapter: false
#   adapter_dim: 8
# head:
#   SurvLayer: cr
#   surv_weight: 1
#   tokens_for_univariate_regression:
#   - 84
#   - 86
#   - 107
#   - 154
#   - 42
#   - 231
#   - 63
#   - 85
#   - 247
#   - 51
#   - 103
#   - 146
#   - 66
#   - 172
#   - 152
#   - 261
#   - 235
#   - 193
#   - 184
#   - 101
#   - 223
#   - 135
#   - 226
#   - 202
#   - 145
#   - 244
#   - 165
#   - 64
#   - 185
#   - 238
#   - 220
#   - 232
#   - 240
#   - 237
#   - 17
#   - 239
#   - 217
#   - 118
#   - 219
#   - 251
#   - 25
#   - 150
#   - 111
#   - 102
#   - 15
#   - 110
#   - 130
#   - 128
#   - 122
#   - 99
#   - 77
#   - 96
#   - 140
#   - 50
#   - 80
#   - 108
#   - 138
#   - 27
#   - 139
#   - 125
#   - 117
#   - 105
#   - 109
#   - 243
#   - 236
#   - 208
#   - 98
#   - 176
#   - 209
#   - 194
#   - 61
#   - 73
#   - 214
#   - 206
#   - 229
#   - 225
#   - 183
#   - 186
#   - 215
#   - 187
#   - 248
#   - 179
#   - 163
#   - 180
#   - 181
#   - 153
#   - 245
#   - 54
#   - 246
#   - 112
#   - 212
#   - 141
#   - 204
#   - 227
#   - 173
#   - 55
#   - 119
#   - 262
#   - 127
#   - 71
#   - 59
#   - 144
#   - 113
#   - 170
#   - 241
#   - 168
#   - 47
#   - 159
#   value_weight: 0.1
# static: true
#
# INFO:root:====================================================================================================
# INFO:root:# Pre-training experiment
# INFO:root:====================================================================================================
# INFO:root:Loading a pre-trained model with the checkpoint path /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/CrossSectionalMLP.ckpt.
# INFO:root:Created Performance metric callback for causal self-supervised tasks.
# INFO:root:Interactive job = True
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /rds/bear-apps/2022a/EL8-ice/software/PyTorch-Lightning/2.1.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/logger_connector.py:67: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
# INFO:root:Testing model.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# SLURM auto-requeueing enabled. Setting signal handlers.
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
# Testing: |          | 0/? [00:00<?, ?it/s]
# WARNING:root:Unable to calculate baseline causal metrics, this sample will be skipped - this will bias metrics.
# torch.Size([6484, 282])
# 265
# torch.Size([4, 282])
# 265
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Projects/CPRD/src/models/survival/custom_callbacks/causal_eval.py:101, in PerformanceMetrics.get_scalar_based_metrics(self, risk_scores, observed_k, _trainer, _pl_module, log_name, suppress_warnings, k_ahead)
#      97 try:
#      98
#      99     # Calculate normalised concordance based on position in ranked risk.
#     100     # event_concordance = np.where(risk_scores == observed_k.cpu().numpy())[0][0] / (len(risk_scores) - 1)
# --> 101     risk_scores = np.argsort(risk_scores) + 1
#     102     event_concordance = np.where(risk_scores == observed_k.cpu().numpy())[0][0] / (len(risk_scores) - 1)
#
# File <__array_function__ internals>:180, in argsort(*args, **kwargs)
#
# File /rds/bear-apps/2022a/EL8-ice/software/SciPy-bundle/2022.05-foss-2022a/lib/python3.10/site-packages/numpy/core/fromnumeric.py:1120, in argsort(a, axis, kind, order)
#    1014 """
#    1015 Returns the indices that would sort an array.
#    1016
#    (...)
#    1118
#    1119 """
# -> 1120 return _wrapfunc(a, 'argsort', axis=axis, kind=kind, order=order)
#
# File /rds/bear-apps/2022a/EL8-ice/software/SciPy-bundle/2022.05-foss-2022a/lib/python3.10/site-packages/numpy/core/fromnumeric.py:54, in _wrapfunc(obj, method, *args, **kwds)
#      53 if bound is None:
# ---> 54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
#
# File /rds/bear-apps/2022a/EL8-ice/software/SciPy-bundle/2022.05-foss-2022a/lib/python3.10/site-packages/numpy/core/fromnumeric.py:43, in _wrapit(obj, method, *args, **kwds)
#      42     wrap = None
# ---> 43 result = getattr(asarray(obj), method)(*args, **kwds)
#      44 if wrap:
#
# File /rds/bear-apps/2022a/EL8-ice/software/PyTorch/2.0.1-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/torch/_tensor.py:970, in Tensor.__array__(self, dtype)
#     969 if dtype is None:
# --> 970     return self.numpy()
#     971 else:
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.
#
# During handling of the above exception, another exception occurred:
#
# NotImplementedError                       Traceback (most recent call last)
# Cell In [11], line 12
#       1 with initialize(version_base=None, config_path="../../SurvivEHR/confs", job_name=""):
#       2     cfg = compose(config_name="config_CompetingRisk11M",
#       3                   overrides=["experiment.run_id='CrossSectionalMLP'",
#       4                              "data.meta_information_path=/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle",
#    (...)
#       9                              "+static=True"
#      10                             ])
# ---> 12 model, dm = run(cfg)
#      13 print(f"Loaded model with {sum(p.numel() for p in model.parameters())/1e6} M parameters")
#      15 wandb.finish()
#
# File /rds/bear-apps/2022a/EL8-ice/software/Hydra/1.3.2-GCCcore-11.3.0/lib/python3.10/site-packages/hydra/main.py:83, in main.<locals>.main_decorator.<locals>.decorated_main(cfg_passthrough)
#      80 @functools.wraps(task_function)
#      81 def decorated_main(cfg_passthrough: Optional[DictConfig] = None) -> Any:
#      82     if cfg_passthrough is not None:
# ---> 83         return task_function(cfg_passthrough)
#      84     else:
#      85         args_parser = get_args_parser()
#
# File ~/Projects/CPRD/examples/modelling/benchmarks/Pretrain/run_experiment.py:140, in run(cfg)
#     138 if cfg.experiment.test:
#     139     logging.info(f"Testing model.")
# --> 140     trainer.test(experiment_instance, dataloaders=dm.test_dataloader())
#     142 return experiment_instance, dm
#
# File /rds/bear-apps/2022a/EL8-ice/software/PyTorch-Lightning/2.1.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py:755, in Trainer.test(self, model, dataloaders, ckpt_path, verbose, datamodule)
#     753 self.state.status = TrainerStatus.RUNNING
#     754 self.testing = True
# --> 755 return call._call_and_handle_interrupt(
#     756     self, self._test_impl, model, dataloaders, ckpt_path, verbose, datamodule
#     757 )
#
# File /rds/bear-apps/2022a/EL8-ice/software/PyTorch-Lightning/2.1.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/pytorch_lightning/trainer/call.py:44, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      42     if trainer.strategy.launcher is not None:
#      43         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 44     return trainer_fn(*args, **kwargs)
#      46 except _TunerExitException:
#      47     _call_teardown_hook(trainer)
#
# File /rds/bear-apps/2022a/EL8-ice/software/PyTorch-Lightning/2.1.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py:795, in Trainer._test_impl(self, model, dataloaders, ckpt_path, verbose, datamodule)
#     791 assert self.state.fn is not None
#     792 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     793     self.state.fn, ckpt_path, model_provided=model_provided, model_connected=self.lightning_module is not None
#     794 )
# --> 795 results = self._run(model, ckpt_path=ckpt_path)
#     796 # remove the tensors from the test results
#     797 results = convert_tensors_to_scalars(results)
#
# File /rds/bear-apps/2022a/EL8-ice/software/PyTorch-Lightning/2.1.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py:990, in Trainer._run(self, model, ckpt_path)
#     985 self._signal_connector.register_signal_handlers()
#     987 # ----------------------------
#     988 # RUN THE TRAINER
#     989 # ----------------------------
# --> 990 results = self._run_stage()
#     992 # ----------------------------
#     993 # POST-Training CLEAN UP
#     994 # ----------------------------
#     995 log.debug(f"{self.__class__.__name__}: trainer tearing down")
#
# File /rds/bear-apps/2022a/EL8-ice/software/PyTorch-Lightning/2.1.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py:1029, in Trainer._run_stage(self)
#    1026 self.lightning_module.zero_grad(**zero_grad_kwargs)
#    1028 if self.evaluating:
# -> 1029     return self._evaluation_loop.run()
#    1030 if self.predicting:
#    1031     return self.predict_loop.run()
#
# File /rds/bear-apps/2022a/EL8-ice/software/PyTorch-Lightning/2.1.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/pytorch_lightning/loops/utilities.py:181, in _no_grad_context.<locals>._decorator(self, *args, **kwargs)
#     179     context_manager = torch.no_grad
#     180 with context_manager():
# --> 181     return loop_run(self, *args, **kwargs)
#
# File /rds/bear-apps/2022a/EL8-ice/software/PyTorch-Lightning/2.1.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/pytorch_lightning/loops/evaluation_loop.py:134, in _EvaluationLoop.run(self)
#     132     self.batch_progress.is_last_batch = data_fetcher.done
#     133     # run step hooks
# --> 134     self._evaluation_step(batch, batch_idx, dataloader_idx, dataloader_iter)
#     135 except StopIteration:
#     136     # this needs to wrap the `*_step` call too (not just `next`) for `dataloader_iter` support
#     137     break
#
# File /rds/bear-apps/2022a/EL8-ice/software/PyTorch-Lightning/2.1.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/pytorch_lightning/loops/evaluation_loop.py:405, in _EvaluationLoop._evaluation_step(self, batch, batch_idx, dataloader_idx, dataloader_iter)
#     400     hook_kwargs = self._build_kwargs(
#     401         batch, batch_idx, dataloader_idx if self._is_sequential and self.num_dataloaders > 1 else None
#     402     )
#     404 hook_name = "on_test_batch_end" if trainer.testing else "on_validation_batch_end"
# --> 405 call._call_callback_hooks(trainer, hook_name, output, *hook_kwargs.values())
#     406 call._call_lightning_module_hook(trainer, hook_name, output, *hook_kwargs.values())
#     408 trainer._logger_connector.on_batch_end()
#
# File /rds/bear-apps/2022a/EL8-ice/software/PyTorch-Lightning/2.1.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/pytorch_lightning/trainer/call.py:208, in _call_callback_hooks(trainer, hook_name, monitoring_callbacks, *args, **kwargs)
#     206     if callable(fn):
#     207         with trainer.profiler.profile(f"[Callback]{callback.state_key}.{hook_name}"):
# --> 208             fn(trainer, trainer.lightning_module, *args, **kwargs)
#     210 if pl_module:
#     211     # restore current_fx when nested context
#     212     pl_module._current_fx_name = prev_fx_name
#
# File ~/Projects/CPRD/src/models/survival/custom_callbacks/causal_eval.py:243, in PerformanceMetrics.on_test_batch_end(self, trainer, pl_module, outputs, batch, batch_idx)
#     241 def on_test_batch_end(self, trainer, pl_module, outputs, batch, batch_idx):
#     242     # Run callback
# --> 243     self.run_callback(_trainer=trainer,
#     244                       _pl_module = pl_module,
#     245                       batch=batch,
#     246                       log_name = "Test:",
#     247                       )
#
# File ~/Projects/CPRD/src/models/survival/custom_callbacks/causal_eval.py:182, in PerformanceMetrics.run_callback(self, _trainer, _pl_module, batch, log_name, plot_outcome_curves, suppress_warnings)
#     179     _observed_outcome_k = k[0][transition]
#     181     # Get the baseline prevalence based concordance metric for each transition
# --> 182     self.get_scalar_based_metrics(_outcome_logits,
#     183                                   _observed_outcome_k,
#     184                                   _trainer,
#     185                                   _pl_module,
#     186                                   log_name=log_name + "_clf",
#     187                                   suppress_warnings=suppress_warnings
#     188                                   )
#     191 else:
#     192     raise NotImplementedError
#
# File ~/Projects/CPRD/src/models/survival/custom_callbacks/causal_eval.py:115, in PerformanceMetrics.get_scalar_based_metrics(self, risk_scores, observed_k, _trainer, _pl_module, log_name, suppress_warnings, k_ahead)
#     113 if suppress_warnings is False:
#     114     logging.warning("Unable to calculate baseline causal metrics, this sample will be skipped - this will bias metrics.")
# --> 115 raise NotImplementedError
#
# NotImplementedError:
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
