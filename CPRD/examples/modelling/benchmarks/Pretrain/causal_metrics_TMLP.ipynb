# %% [markdown]
# # Testing the pre-trained Transfomer + NN classifier for next event prediction
#
# This model uses the same Transformer input layer as SurvivEHR, but predicts logits to classifier next event

# %%
import os
from pathlib import Path
import sys
node_type = os.getenv('BB_CPU')
venv_dir = f'/rds/homes/g/gaddcz/Projects/CPRD/virtual-envTorch2.0-{node_type}'
venv_site_pkgs = Path(venv_dir) / 'lib' / f'python{sys.version_info.major}.{sys.version_info.minor}' / 'site-packages'
if venv_site_pkgs.exists():
    sys.path.insert(0, str(venv_site_pkgs))
    print(f"Added path '{venv_site_pkgs}' at start of search paths.")
else:
    print(f"Path '{venv_site_pkgs}' not found. Check that it exists and/or that it exists for node-type '{node_type}'.")

# %load_ext autoreload
# %autoreload 2

# %env SLURM_NTASKS_PER_NODE=28
# Out:
# Added path '/rds/homes/g/gaddcz/Projects/CPRD/virtual-envTorch2.0-icelake/lib/python3.10/site-packages' at start of search paths.
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# env: SLURM_NTASKS_PER_NODE=28

# %%
import torch
import logging
from hydra import compose, initialize

from setup_causal_mlp_experiment import CausalMLPExperiment, setup_mlp_experiment
from setup_causal_t_mlp_experiment import CausalTMLPExperiment, setup_t_mlp_experiment
from SurvivEHR.examples.modelling.benchmarks.Pretrain.run_experiment import run

torch.manual_seed(1337)
logging.basicConfig(level=logging.INFO)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# device = "cpu"    # if more informative debugging statements are needed
print(f"Using device: {device}.")

# %env SLURM_NTASKS_PER_NODE=28
# Out:
# Using device: cuda.
# env: SLURM_NTASKS_PER_NODE=28

# %% [markdown]
# # Create and run pre-trained experiment

# %%
with initialize(version_base=None, config_path="../../SurvivEHR/confs", job_name=""):
    cfg = compose(config_name="config_CompetingRisk11M", 
                  overrides=[
                             "experiment.run_id='TransformerMLP'",
                             # "data.meta_information_path=/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle",
                             # "data.min_workers=12",
                             # "experiment.train=False",
                             # "experiment.test=True",
                             # "experiment.log=True",
                             "+static=False",
                             "experiment.project_name='Evaluating pre-trained models'",
                             # f"experiment.run_id='{pre_trained_model}'",
                             "experiment.train=False",
                             "experiment.test=True",
                             "data.batch_size=128",
                             "data.meta_information_path=/rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle",
                             "data.min_workers=12",
                             "optim.limit_test_batches=0.035",
                            ])

model, dm = run(cfg)
print(f"Loaded model with {sum(p.numel() for p in model.parameters())/1e6} M parameters")
# Out:
# INFO:root:Running cr on 72 CPUs and 1 GPUs
# INFO:root:====================================================================================================
# INFO:root:# Loading DataModule for dataset /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/. This will be loaded in causal form.
# INFO:root:====================================================================================================
# INFO:root:Creating unsupervised collator for DataModule
# INFO:root:Using meta information from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle
# INFO:root:Using train file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/file_row_count_dict_train.pickle
# INFO:root:Using test file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/file_row_count_dict_test.pickle
# INFO:root:Using val file-row count dictionary from /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/file_row_count_dict_val.pickle
# INFO:root:Tokenzier created based on 7,555,415,275 tokens
# INFO:root:Using tabular tokenizer, created from meta information and containing 265 tokens
# INFO:root:Set seed to 1337
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/split=train/ dataset, with 23,613,894 samples
# INFO:root:Set seed to 42
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/split=test/ dataset, with 1,508,320 samples
# INFO:root:Set seed to 42
# INFO:root:Loaded /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/split=val/ dataset, with 1,426,714 samples
# INFO:root:is_decoder: true
# data:
#   batch_size: 128
#   unk_freq_threshold: 0.0
#   min_workers: 12
#   global_diagnoses: false
#   repeating_events: true
#   path_to_db: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/cprd.db
#   path_to_ds: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/
#   meta_information_path: /rds/projects/g/gokhalkm-optimal/OPTIMAL_MASTER_DATASET/data/FoundationalModel/PreTrain/meta_information_QuantJenny.pickle
#   subsample_training: null
# experiment:
#   type: pre-train
#   project_name: Evaluating pre-trained models
#   run_id: TransformerMLP
#   fine_tune_id: null
#   notes: null
#   tags: null
#   train: false
#   test: true
#   verbose: true
#   seed: 1337
#   log: true
#   log_dir: /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/
#   ckpt_dir: /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/
# fine_tuning:
#   fine_tune_outcomes: null
#   custom_outcome_method:
#     _target_: null
#   custom_stratification_method:
#     _target_: null
#   use_callbacks:
#     hidden_embedding: true
#     performance_metrics: true
#     rmst: false
#   head:
#     surv_weight: 1
#     value_weight: 0
#     learning_rate: 0.0005
# optim:
#   num_epochs: 1
#   learning_rate: 0.0003
#   scheduler_warmup: true
#   scheduler: decaycawarmrestarts
#   scheduler_periods: 10000
#   learning_rate_decay: 0.8
#   val_check_interval: 2500
#   early_stop: true
#   early_stop_patience: 30
#   log_every_n_steps: 20
#   limit_val_batches: 0.025
#   limit_test_batches: 0.035
#   accumulate_grad_batches: 1
# transformer:
#   block_type: Neo
#   block_size: 256
#   n_layer: 6
#   n_head: 6
#   n_embd: 384
#   layer_norm_bias: false
#   attention_type: global
#   bias: true
#   dropout: 0.0
#   attention_dropout: 0.0
#   resid_dropout: 0.0
#   private_heads: 0
#   use_fine_tune_adapter: false
#   adapter_dim: 8
# head:
#   SurvLayer: cr
#   surv_weight: 1
#   tokens_for_univariate_regression:
#   - 84
#   - 86
#   - 107
#   - 154
#   - 42
#   - 231
#   - 63
#   - 85
#   - 247
#   - 51
#   - 103
#   - 146
#   - 66
#   - 172
#   - 152
#   - 261
#   - 235
#   - 193
#   - 184
#   - 101
#   - 223
#   - 135
#   - 226
#   - 202
#   - 145
#   - 244
#   - 165
#   - 64
#   - 185
#   - 238
#   - 220
#   - 232
#   - 240
#   - 237
#   - 17
#   - 239
#   - 217
#   - 118
#   - 219
#   - 251
#   - 25
#   - 150
#   - 111
#   - 102
#   - 15
#   - 110
#   - 130
#   - 128
#   - 122
#   - 99
#   - 77
#   - 96
#   - 140
#   - 50
#   - 80
#   - 108
#   - 138
#   - 27
#   - 139
#   - 125
#   - 117
#   - 105
#   - 109
#   - 243
#   - 236
#   - 208
#   - 98
#   - 176
#   - 209
#   - 194
#   - 61
#   - 73
#   - 214
#   - 206
#   - 229
#   - 225
#   - 183
#   - 186
#   - 215
#   - 187
#   - 248
#   - 179
#   - 163
#   - 180
#   - 181
#   - 153
#   - 245
#   - 54
#   - 246
#   - 112
#   - 212
#   - 141
#   - 204
#   - 227
#   - 173
#   - 55
#   - 119
#   - 262
#   - 127
#   - 71
#   - 59
#   - 144
#   - 113
#   - 170
#   - 241
#   - 168
#   - 47
#   - 159
#   value_weight: 0.1
# static: false
#
# INFO:root:====================================================================================================
# INFO:root:# Pre-training experiment
# INFO:root:====================================================================================================
# INFO:root:Loading a pre-trained model with the checkpoint path /rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/checkpoints/TransformerMLP.ckpt.
# INFO:torch.distributed.nn.jit.instantiator:Created a temporary directory at /tmp/tmpxgx7eulk
# INFO:torch.distributed.nn.jit.instantiator:Writing /tmp/tmpxgx7eulk/_remote_module_non_scriptable.py
# INFO:root:Using Temporal Positional Encoding. This module uses the patient's age at an event within their time series.
# INFO:root:Created PerformanceMetrics callback for causal self-supervised tasks.
# INFO:root:
# INFO:root:Interactive job = True
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# INFO:root:Testing model.
# wandb version 0.19.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.6
# Run data is saved locally in <code>/rds/projects/s/subramaa-mum-predict/CharlesGadd_Oxford/FoundationModelOutput/wandb/run-20250603_155447-jvm6o7pu</code>
# Syncing run <strong><a href="https://wandb.ai/cwlgadd/Evaluating%20pre-trained%20models/runs/jvm6o7pu" target="_blank">TransformerMLP</a></strong> to <a href="https://wandb.ai/cwlgadd/Evaluating%20pre-trained%20models" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# SLURM auto-requeueing enabled. Setting signal handlers.
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                   Test metric                   ┃                  DataLoader 0                   ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │     Test:+0_LookAheadMetricsclf_no_stratify     │               0.7144243947007767                │
# │ Test:+0_LookAheadMetricsprevalence_no_stratify  │               0.8549209927966827                │
# │    Test:+10_LookAheadMetricsclf_no_stratify     │               0.7074754513778907                │
# │ Test:+10_LookAheadMetricsprevalence_no_stratify │               0.8498032617479898                │
# │    Test:+13_LookAheadMetricsclf_no_stratify     │               0.6989734299516907                │
# │ Test:+13_LookAheadMetricsprevalence_no_stratify │                0.848335813082052                │
# │    Test:+16_LookAheadMetricsclf_no_stratify     │               0.7054141034404199                │
# │ Test:+16_LookAheadMetricsprevalence_no_stratify │               0.8504674233111297                │
# │    Test:+19_LookAheadMetricsclf_no_stratify     │               0.7187463437463438                │
# │ Test:+19_LookAheadMetricsprevalence_no_stratify │               0.8518284716003348                │
# │     Test:+1_LookAheadMetricsclf_no_stratify     │               0.7127249357326487                │
# │ Test:+1_LookAheadMetricsprevalence_no_stratify  │               0.8554057884602225                │
# │     Test:+2_LookAheadMetricsclf_no_stratify     │                0.717692801026135                │
# │ Test:+2_LookAheadMetricsprevalence_no_stratify  │               0.8562878467821434                │
# │     Test:+3_LookAheadMetricsclf_no_stratify     │               0.7110478077780534                │
# │ Test:+3_LookAheadMetricsprevalence_no_stratify  │                0.856383584919344                │
# │     Test:+4_LookAheadMetricsclf_no_stratify     │               0.7157499363381717                │
# │ Test:+4_LookAheadMetricsprevalence_no_stratify  │               0.8553855002076877                │
# │     Test:+7_LookAheadMetricsclf_no_stratify     │               0.7062289562289563                │
# │ Test:+7_LookAheadMetricsprevalence_no_stratify  │               0.8501297603959204                │
# │        Test:CausalMetricsclf_no_stratify        │               0.7131728676584986                │
# │      Test:CausalMetricsclf_stratify_by_100      │               0.08585858585858586               │
# │      Test:CausalMetricsclf_stratify_by_101      │               0.3686868686868687                │
# │      Test:CausalMetricsclf_stratify_by_104      │               0.39520202020202017               │
# │      Test:CausalMetricsclf_stratify_by_106      │               0.06792929292929294               │
# │      Test:CausalMetricsclf_stratify_by_107      │               0.7154356060606061                │
# │      Test:CausalMetricsclf_stratify_by_11       │               0.2878787878787879                │
# │      Test:CausalMetricsclf_stratify_by_110      │               0.5994318181818182                │
# │      Test:CausalMetricsclf_stratify_by_112      │               0.1274703557312253                │
# │      Test:CausalMetricsclf_stratify_by_113      │               0.4517045454545454                │
# │      Test:CausalMetricsclf_stratify_by_114      │                0.457070707070707                │
# │      Test:CausalMetricsclf_stratify_by_115      │               0.5964646464646465                │
# │      Test:CausalMetricsclf_stratify_by_116      │                0.323030303030303                │
# │      Test:CausalMetricsclf_stratify_by_118      │               0.8059440559440562                │
# │      Test:CausalMetricsclf_stratify_by_119      │               0.6567550505050505                │
# │      Test:CausalMetricsclf_stratify_by_120      │               0.6256313131313131                │
# │      Test:CausalMetricsclf_stratify_by_121      │               0.5574494949494949                │
# │      Test:CausalMetricsclf_stratify_by_123      │               0.2046760710553814                │
# │      Test:CausalMetricsclf_stratify_by_124      │               0.8774621212121211                │
# │      Test:CausalMetricsclf_stratify_by_126      │               0.1318542568542569                │
# │      Test:CausalMetricsclf_stratify_by_127      │               0.8077651515151516                │
# │      Test:CausalMetricsclf_stratify_by_129      │               0.27124505928853754               │
# │      Test:CausalMetricsclf_stratify_by_130      │               0.2928503787878788                │
# │      Test:CausalMetricsclf_stratify_by_131      │               0.5653263403263402                │
# │      Test:CausalMetricsclf_stratify_by_133      │               0.3876262626262627                │
# │      Test:CausalMetricsclf_stratify_by_134      │               0.7716942148760331                │
# │      Test:CausalMetricsclf_stratify_by_135      │               0.4284511784511784                │
# │      Test:CausalMetricsclf_stratify_by_136      │               0.6116310160427808                │
# │      Test:CausalMetricsclf_stratify_by_141      │               0.6287878787878788                │
# │      Test:CausalMetricsclf_stratify_by_142      │               0.27005853994490353               │
# │      Test:CausalMetricsclf_stratify_by_143      │               0.11423898071625342               │
# │      Test:CausalMetricsclf_stratify_by_144      │               0.07481060606060606               │
# │      Test:CausalMetricsclf_stratify_by_145      │               0.06186868686868687               │
# │      Test:CausalMetricsclf_stratify_by_146      │               0.45713463751438466               │
# │      Test:CausalMetricsclf_stratify_by_148      │               0.48922413793103475               │
# │      Test:CausalMetricsclf_stratify_by_149      │                0.161682615629984                │
# │      Test:CausalMetricsclf_stratify_by_150      │               0.7551515151515151                │
# │      Test:CausalMetricsclf_stratify_by_151      │               0.5766359244620113                │
# │      Test:CausalMetricsclf_stratify_by_152      │               0.27389277389277394               │
# │      Test:CausalMetricsclf_stratify_by_153      │               0.6607187578261962                │
# │      Test:CausalMetricsclf_stratify_by_154      │              0.030833333333333338               │
# │      Test:CausalMetricsclf_stratify_by_155      │               0.8541666666666667                │
# │      Test:CausalMetricsclf_stratify_by_156      │               0.6702317290552585                │
# │      Test:CausalMetricsclf_stratify_by_157      │               0.4702611218568665                │
# │      Test:CausalMetricsclf_stratify_by_158      │               0.6398172905525847                │
# │      Test:CausalMetricsclf_stratify_by_159      │              0.017424242424242425               │
# │      Test:CausalMetricsclf_stratify_by_160      │               0.2703823953823954                │
# │      Test:CausalMetricsclf_stratify_by_161      │               0.7380952380952382                │
# │      Test:CausalMetricsclf_stratify_by_162      │               0.9484126984126983                │
# │      Test:CausalMetricsclf_stratify_by_163      │               0.08641319739450583               │
# │      Test:CausalMetricsclf_stratify_by_164      │               0.7376395534290273                │
# │      Test:CausalMetricsclf_stratify_by_165      │               0.5493071743071742                │
# │      Test:CausalMetricsclf_stratify_by_166      │               0.6634199134199134                │
# │      Test:CausalMetricsclf_stratify_by_167      │               0.4165495157763198                │
# │      Test:CausalMetricsclf_stratify_by_168      │               0.7887878787878787                │
# │      Test:CausalMetricsclf_stratify_by_169      │               0.7458175505050505                │
# │      Test:CausalMetricsclf_stratify_by_170      │               0.3123205741626794                │
# │      Test:CausalMetricsclf_stratify_by_171      │               0.4002287021154945                │
# │      Test:CausalMetricsclf_stratify_by_172      │               0.8232163406214037                │
# │      Test:CausalMetricsclf_stratify_by_173      │               0.6802912849424481                │
# │      Test:CausalMetricsclf_stratify_by_174      │                0.621103896103896                │
# │      Test:CausalMetricsclf_stratify_by_175      │               0.8164983164983165                │
# │      Test:CausalMetricsclf_stratify_by_176      │               0.07323232323232325               │
# │      Test:CausalMetricsclf_stratify_by_177      │                0.705918560606061                │
# │      Test:CausalMetricsclf_stratify_by_178      │               0.4009940676607343                │
# │      Test:CausalMetricsclf_stratify_by_179      │               0.5050282757148955                │
# │      Test:CausalMetricsclf_stratify_by_180      │               0.9900793650793668                │
# │      Test:CausalMetricsclf_stratify_by_181      │               0.9706996434937608                │
# │      Test:CausalMetricsclf_stratify_by_182      │               0.6026199494949491                │
# │      Test:CausalMetricsclf_stratify_by_183      │                0.816442199775533                │
# │      Test:CausalMetricsclf_stratify_by_184      │               0.4768181818181817                │
# │      Test:CausalMetricsclf_stratify_by_185      │               0.8242424242424243                │
# │      Test:CausalMetricsclf_stratify_by_186      │                0.568539727988547                │
# │      Test:CausalMetricsclf_stratify_by_187      │               0.9601736706689551                │
# │      Test:CausalMetricsclf_stratify_by_188      │               0.23124098124098125               │
# │      Test:CausalMetricsclf_stratify_by_189      │               0.5427787044759522                │
# │      Test:CausalMetricsclf_stratify_by_190      │                0.92010101010101                 │
# │      Test:CausalMetricsclf_stratify_by_191      │               0.3790404040404036                │
# │      Test:CausalMetricsclf_stratify_by_192      │               0.7469904524699046                │
# │      Test:CausalMetricsclf_stratify_by_193      │               0.7732683982683987                │
# │      Test:CausalMetricsclf_stratify_by_194      │               0.8881093544137026                │
# │      Test:CausalMetricsclf_stratify_by_195      │               0.11537878787878786               │
# │      Test:CausalMetricsclf_stratify_by_196      │               0.7272255752546206                │
# │      Test:CausalMetricsclf_stratify_by_197      │               0.8363636363636364                │
# │      Test:CausalMetricsclf_stratify_by_198      │               0.8291947250280585                │
# │      Test:CausalMetricsclf_stratify_by_199      │               0.8673351158645277                │
# │      Test:CausalMetricsclf_stratify_by_200      │               0.8250062609566747                │
# │      Test:CausalMetricsclf_stratify_by_201      │               0.39865272038567523               │
# │      Test:CausalMetricsclf_stratify_by_202      │               0.21210467116580656               │
# │      Test:CausalMetricsclf_stratify_by_203      │                0.849466891133558                │
# │      Test:CausalMetricsclf_stratify_by_204      │               0.3333573072497124                │
# │      Test:CausalMetricsclf_stratify_by_205      │               0.4190010570824524                │
# │      Test:CausalMetricsclf_stratify_by_206      │               0.8083094726795519                │
# │      Test:CausalMetricsclf_stratify_by_207      │               0.8271867985409656                │
# │      Test:CausalMetricsclf_stratify_by_208      │               0.6615924725680825                │
# │      Test:CausalMetricsclf_stratify_by_209      │               0.7811547426932046                │
# │      Test:CausalMetricsclf_stratify_by_210      │               0.8395278754394774                │
# │      Test:CausalMetricsclf_stratify_by_211      │               0.3947040278562018                │
# │      Test:CausalMetricsclf_stratify_by_212      │               0.7268464386631589                │
# │      Test:CausalMetricsclf_stratify_by_213      │               0.32315694255992766               │
# │      Test:CausalMetricsclf_stratify_by_214      │               0.6731971614883009                │
# │      Test:CausalMetricsclf_stratify_by_215      │               0.9591677646025476                │
# │      Test:CausalMetricsclf_stratify_by_216      │               0.6507654671717172                │
# │      Test:CausalMetricsclf_stratify_by_217      │               0.7492101105845175                │
# │      Test:CausalMetricsclf_stratify_by_218      │               0.8617009511170094                │
# │      Test:CausalMetricsclf_stratify_by_219      │               0.39968207595806843               │
# │      Test:CausalMetricsclf_stratify_by_220      │               0.9371793724648046                │
# │      Test:CausalMetricsclf_stratify_by_221      │               0.27504734848484846               │
# │      Test:CausalMetricsclf_stratify_by_222      │               0.6522228867623605                │
# │      Test:CausalMetricsclf_stratify_by_223      │               0.6234081112852664                │
# │      Test:CausalMetricsclf_stratify_by_224      │               0.8831668331668341                │
# │      Test:CausalMetricsclf_stratify_by_225      │               0.6449694311536419                │
# │      Test:CausalMetricsclf_stratify_by_226      │               0.7472217004758334                │
# │      Test:CausalMetricsclf_stratify_by_227      │               0.7238702431289635                │
# │      Test:CausalMetricsclf_stratify_by_228      │                0.647050865800866                │
# │      Test:CausalMetricsclf_stratify_by_229      │               0.6723211496407381                │
# │      Test:CausalMetricsclf_stratify_by_230      │               0.8080195612844889                │
# │      Test:CausalMetricsclf_stratify_by_231      │               0.9159752284752304                │
# │      Test:CausalMetricsclf_stratify_by_232      │               0.8472200821777085                │
# │      Test:CausalMetricsclf_stratify_by_233      │               0.06574440052700932               │
# │      Test:CausalMetricsclf_stratify_by_234      │                0.834970723167935                │
# │      Test:CausalMetricsclf_stratify_by_235      │               0.8213859258079925                │
# │      Test:CausalMetricsclf_stratify_by_236      │               0.7556914975995048                │
# │      Test:CausalMetricsclf_stratify_by_237      │               0.8956458785810318                │
# │      Test:CausalMetricsclf_stratify_by_238      │               0.8556876061120542                │
# │      Test:CausalMetricsclf_stratify_by_239      │               0.9621084152334202                │
# │      Test:CausalMetricsclf_stratify_by_240      │               0.9744829638446737                │
# │      Test:CausalMetricsclf_stratify_by_241      │               0.6731534090909098                │
# │      Test:CausalMetricsclf_stratify_by_242      │               0.6373230117771601                │
# │      Test:CausalMetricsclf_stratify_by_243      │               0.7710121212121208                │
# │      Test:CausalMetricsclf_stratify_by_244      │               0.8901878787878775                │
# │      Test:CausalMetricsclf_stratify_by_245      │               0.7644691399286989                │
# │      Test:CausalMetricsclf_stratify_by_246      │               0.9927729460671746                │
# │      Test:CausalMetricsclf_stratify_by_247      │               0.32264911719776895               │
# │      Test:CausalMetricsclf_stratify_by_248      │               0.8913885161578887                │
# │      Test:CausalMetricsclf_stratify_by_249      │               0.9132853963362433                │
# │      Test:CausalMetricsclf_stratify_by_25       │               0.5265151515151515                │
# │      Test:CausalMetricsclf_stratify_by_250      │               0.5247923512230742                │
# │      Test:CausalMetricsclf_stratify_by_251      │               0.6824357348550895                │
# │      Test:CausalMetricsclf_stratify_by_252      │               0.9083401583401594                │
# │      Test:CausalMetricsclf_stratify_by_253      │               0.8406565656565663                │
# │      Test:CausalMetricsclf_stratify_by_254      │               0.22923805684337814               │
# │      Test:CausalMetricsclf_stratify_by_255      │               0.9289502164502165                │
# │      Test:CausalMetricsclf_stratify_by_256      │                0.952609798424776                │
# │      Test:CausalMetricsclf_stratify_by_257      │               0.9568157141447062                │
# │      Test:CausalMetricsclf_stratify_by_258      │               0.9961874444773499                │
# │      Test:CausalMetricsclf_stratify_by_259      │              0.032521212121212326               │
# │      Test:CausalMetricsclf_stratify_by_260      │                0.734283711147465                │
# │      Test:CausalMetricsclf_stratify_by_261      │               0.9523273976882218                │
# │      Test:CausalMetricsclf_stratify_by_262      │               0.9615786309632945                │
# │      Test:CausalMetricsclf_stratify_by_263      │                0.811246040126713                │
# │      Test:CausalMetricsclf_stratify_by_264      │               0.4027816272480909                │
# │      Test:CausalMetricsclf_stratify_by_27       │               0.4962121212121212                │
# │      Test:CausalMetricsclf_stratify_by_31       │               0.2727272727272727                │
# │      Test:CausalMetricsclf_stratify_by_34       │               0.5593434343434344                │
# │      Test:CausalMetricsclf_stratify_by_38       │               0.48863636363636365               │
# │      Test:CausalMetricsclf_stratify_by_39       │               0.8181818181818182                │
# │      Test:CausalMetricsclf_stratify_by_40       │               0.3106060606060606                │
# │      Test:CausalMetricsclf_stratify_by_41       │               0.5587121212121212                │
# │      Test:CausalMetricsclf_stratify_by_44       │               0.08712121212121213               │
# │      Test:CausalMetricsclf_stratify_by_47       │               0.45454545454545453               │
# │      Test:CausalMetricsclf_stratify_by_48       │               0.3181818181818182                │
# │      Test:CausalMetricsclf_stratify_by_51       │               0.3090909090909091                │
# │      Test:CausalMetricsclf_stratify_by_55       │               0.6287878787878788                │
# │      Test:CausalMetricsclf_stratify_by_57       │               0.43560606060606055               │
# │      Test:CausalMetricsclf_stratify_by_58       │               0.7840909090909091                │
# │      Test:CausalMetricsclf_stratify_by_60       │               0.03409090909090909               │
# │      Test:CausalMetricsclf_stratify_by_63       │               0.6401515151515151                │
# │      Test:CausalMetricsclf_stratify_by_65       │               0.4621212121212121                │
# │      Test:CausalMetricsclf_stratify_by_67       │               0.07954545454545454               │
# │      Test:CausalMetricsclf_stratify_by_70       │               0.03787878787878787               │
# │      Test:CausalMetricsclf_stratify_by_71       │               0.3333333333333333                │
# │      Test:CausalMetricsclf_stratify_by_75       │               0.7571548821548822                │
# │      Test:CausalMetricsclf_stratify_by_78       │               0.11742424242424243               │
# │      Test:CausalMetricsclf_stratify_by_79       │               0.7234848484848485                │
# │      Test:CausalMetricsclf_stratify_by_80       │               0.13690476190476192               │
# │      Test:CausalMetricsclf_stratify_by_81       │               0.11931818181818182               │
# │      Test:CausalMetricsclf_stratify_by_82       │               0.6193181818181818                │
# │      Test:CausalMetricsclf_stratify_by_83       │               0.8049242424242424                │
# │      Test:CausalMetricsclf_stratify_by_84       │               0.5145833333333334                │
# │      Test:CausalMetricsclf_stratify_by_85       │               0.48863636363636365               │
# │      Test:CausalMetricsclf_stratify_by_89       │              0.013257575757575758               │
# │      Test:CausalMetricsclf_stratify_by_91       │              0.027777777777777776               │
# │      Test:CausalMetricsclf_stratify_by_93       │              0.010101010101010102               │
# │      Test:CausalMetricsclf_stratify_by_94       │                0.552432216905901                │
# │      Test:CausalMetricsclf_stratify_by_95       │               0.9431818181818182                │
# │      Test:CausalMetricsclf_stratify_by_97       │               0.23538961038961034               │
# │      Test:CausalMetricsclf_stratify_by_98       │                0.672979797979798                │
# │      Test:CausalMetricsclf_stratify_by_99       │               0.8825757575757576                │
# │    Test:CausalMetricsprevalence_no_stratify     │               0.8626828301681702                │
# │  Test:CausalMetricsprevalence_stratify_by_100   │                0.376425855513308                │
# │  Test:CausalMetricsprevalence_stratify_by_101   │               0.38022813688212925               │
# │  Test:CausalMetricsprevalence_stratify_by_104   │               0.3916349809885931                │
# │  Test:CausalMetricsprevalence_stratify_by_106   │               0.3992395437262359                │
# │  Test:CausalMetricsprevalence_stratify_by_107   │               0.4030418250950571                │
# │   Test:CausalMetricsprevalence_stratify_by_11   │               0.03802281368821293               │
# │  Test:CausalMetricsprevalence_stratify_by_110   │               0.41444866920152096               │
# │  Test:CausalMetricsprevalence_stratify_by_112   │               0.42205323193916355               │
# │  Test:CausalMetricsprevalence_stratify_by_113   │               0.4258555133079848                │
# │  Test:CausalMetricsprevalence_stratify_by_114   │               0.42965779467680604               │
# │  Test:CausalMetricsprevalence_stratify_by_115   │               0.43346007604562725               │
# │  Test:CausalMetricsprevalence_stratify_by_116   │               0.4372623574144487                │
# │  Test:CausalMetricsprevalence_stratify_by_118   │               0.4448669201520912                │
# │  Test:CausalMetricsprevalence_stratify_by_119   │               0.44866920152091183               │
# │  Test:CausalMetricsprevalence_stratify_by_120   │               0.45247148288973377               │
# │  Test:CausalMetricsprevalence_stratify_by_121   │               0.4562737642585551                │
# │  Test:CausalMetricsprevalence_stratify_by_123   │               0.4638783269961979                │
# │  Test:CausalMetricsprevalence_stratify_by_124   │               0.46768060836501907               │
# │  Test:CausalMetricsprevalence_stratify_by_126   │               0.4752851711026616                │
# │  Test:CausalMetricsprevalence_stratify_by_127   │                0.479087452471483                │
# │  Test:CausalMetricsprevalence_stratify_by_129   │               0.48669201520912553               │
# │  Test:CausalMetricsprevalence_stratify_by_130   │               0.49049429657794685               │
# │  Test:CausalMetricsprevalence_stratify_by_131   │               0.49429657794676896               │
# │  Test:CausalMetricsprevalence_stratify_by_133   │               0.5019011406844106                │
# │  Test:CausalMetricsprevalence_stratify_by_134   │               0.5057034220532319                │
# │  Test:CausalMetricsprevalence_stratify_by_135   │               0.5095057034220533                │
# │  Test:CausalMetricsprevalence_stratify_by_136   │               0.5133079847908741                │
# │  Test:CausalMetricsprevalence_stratify_by_141   │                0.532319391634981                │
# │  Test:CausalMetricsprevalence_stratify_by_142   │                0.536121673003802                │
# │  Test:CausalMetricsprevalence_stratify_by_143   │                0.539923954372624                │
# │  Test:CausalMetricsprevalence_stratify_by_144   │               0.5437262357414447                │
# │  Test:CausalMetricsprevalence_stratify_by_145   │               0.5475285171102662                │
# │  Test:CausalMetricsprevalence_stratify_by_146   │               0.5513307984790876                │
# │  Test:CausalMetricsprevalence_stratify_by_148   │               0.5589353612167296                │
# │  Test:CausalMetricsprevalence_stratify_by_149   │               0.5627376425855521                │
# │  Test:CausalMetricsprevalence_stratify_by_150   │               0.5665399239543727                │
# │  Test:CausalMetricsprevalence_stratify_by_151   │               0.5703422053231935                │
# │  Test:CausalMetricsprevalence_stratify_by_152   │               0.5741444866920152                │
# │  Test:CausalMetricsprevalence_stratify_by_153   │               0.5779467680608357                │
# │  Test:CausalMetricsprevalence_stratify_by_154   │               0.5817490494296573                │
# │  Test:CausalMetricsprevalence_stratify_by_155   │               0.5855513307984791                │
# │  Test:CausalMetricsprevalence_stratify_by_156   │               0.5893536121673008                │
# │  Test:CausalMetricsprevalence_stratify_by_157   │               0.5931558935361212                │
# │  Test:CausalMetricsprevalence_stratify_by_158   │               0.5969581749049425                │
# │  Test:CausalMetricsprevalence_stratify_by_159   │               0.6007604562737643                │
# │  Test:CausalMetricsprevalence_stratify_by_160   │               0.6045627376425854                │
# │  Test:CausalMetricsprevalence_stratify_by_161   │               0.6083650190114078                │
# │  Test:CausalMetricsprevalence_stratify_by_162   │               0.6121673003802284                │
# │  Test:CausalMetricsprevalence_stratify_by_163   │                0.615969581749049                │
# │  Test:CausalMetricsprevalence_stratify_by_164   │               0.6197718631178707                │
# │  Test:CausalMetricsprevalence_stratify_by_165   │               0.6235741444866912                │
# │  Test:CausalMetricsprevalence_stratify_by_166   │               0.6273764258555133                │
# │  Test:CausalMetricsprevalence_stratify_by_167   │               0.6311787072243358                │
# │  Test:CausalMetricsprevalence_stratify_by_168   │               0.6349809885931562                │
# │  Test:CausalMetricsprevalence_stratify_by_169   │               0.6387832699619767                │
# │  Test:CausalMetricsprevalence_stratify_by_170   │                0.642585551330798                │
# │  Test:CausalMetricsprevalence_stratify_by_171   │               0.6463878326996174                │
# │  Test:CausalMetricsprevalence_stratify_by_172   │               0.6501901140684417                │
# │  Test:CausalMetricsprevalence_stratify_by_173   │                0.653992395437262                │
# │  Test:CausalMetricsprevalence_stratify_by_174   │               0.6577946768060839                │
# │  Test:CausalMetricsprevalence_stratify_by_175   │               0.6615969581749045                │
# │  Test:CausalMetricsprevalence_stratify_by_176   │               0.6653992395437258                │
# │  Test:CausalMetricsprevalence_stratify_by_177   │               0.6692015209125464                │
# │  Test:CausalMetricsprevalence_stratify_by_178   │               0.6730038022813708                │
# │  Test:CausalMetricsprevalence_stratify_by_179   │               0.6768060836501868                │
# │  Test:CausalMetricsprevalence_stratify_by_180   │               0.6806083650190117                │
# │  Test:CausalMetricsprevalence_stratify_by_181   │               0.6844106463878322                │
# │  Test:CausalMetricsprevalence_stratify_by_182   │               0.6882129277566531                │
# │  Test:CausalMetricsprevalence_stratify_by_183   │               0.6920152091254733                │
# │  Test:CausalMetricsprevalence_stratify_by_184   │               0.6958174904942973                │
# │  Test:CausalMetricsprevalence_stratify_by_185   │               0.6996197718631177                │
# │  Test:CausalMetricsprevalence_stratify_by_186   │               0.7034220532319374                │
# │  Test:CausalMetricsprevalence_stratify_by_187   │               0.7072243346007637                │
# │  Test:CausalMetricsprevalence_stratify_by_188   │               0.7110266159695826                │
# │  Test:CausalMetricsprevalence_stratify_by_189   │               0.7148288973384025                │
# │  Test:CausalMetricsprevalence_stratify_by_190   │                0.718631178707225                │
# │  Test:CausalMetricsprevalence_stratify_by_191   │               0.7224334600760467                │
# │  Test:CausalMetricsprevalence_stratify_by_192   │               0.7262357414448671                │
# │  Test:CausalMetricsprevalence_stratify_by_193   │               0.7300380228136875                │
# │  Test:CausalMetricsprevalence_stratify_by_194   │               0.7338403041825081                │
# │  Test:CausalMetricsprevalence_stratify_by_195   │               0.7376425855513306                │
# │  Test:CausalMetricsprevalence_stratify_by_196   │               0.7414448669201497                │
# │  Test:CausalMetricsprevalence_stratify_by_197   │               0.7452471482889734                │
# │  Test:CausalMetricsprevalence_stratify_by_198   │               0.7490494296577949                │
# │  Test:CausalMetricsprevalence_stratify_by_199   │               0.7528517110266153                │
# │  Test:CausalMetricsprevalence_stratify_by_200   │               0.7566539923954361                │
# │  Test:CausalMetricsprevalence_stratify_by_201   │               0.7604562737642592                │
# │  Test:CausalMetricsprevalence_stratify_by_202   │                0.764258555133078                │
# │  Test:CausalMetricsprevalence_stratify_by_203   │               0.7680608365019019                │
# │  Test:CausalMetricsprevalence_stratify_by_204   │               0.7718631178707158                │
# │  Test:CausalMetricsprevalence_stratify_by_205   │               0.7756653992395429                │
# │  Test:CausalMetricsprevalence_stratify_by_206   │               0.7794676806083684                │
# │  Test:CausalMetricsprevalence_stratify_by_207   │               0.7832699619771852                │
# │  Test:CausalMetricsprevalence_stratify_by_208   │               0.7870722433460138                │
# │  Test:CausalMetricsprevalence_stratify_by_209   │                0.790874524714831                │
# │  Test:CausalMetricsprevalence_stratify_by_210   │                0.794676806083648                │
# │  Test:CausalMetricsprevalence_stratify_by_211   │               0.7984790874524759                │
# │  Test:CausalMetricsprevalence_stratify_by_212   │               0.8022813688212963                │
# │  Test:CausalMetricsprevalence_stratify_by_213   │               0.8060836501901127                │
# │  Test:CausalMetricsprevalence_stratify_by_214   │               0.8098859315589376                │
# │  Test:CausalMetricsprevalence_stratify_by_215   │               0.8136882129277554                │
# │  Test:CausalMetricsprevalence_stratify_by_216   │                0.817490494296578                │
# │  Test:CausalMetricsprevalence_stratify_by_217   │               0.8212927756654119                │
# │  Test:CausalMetricsprevalence_stratify_by_218   │               0.8250950570342191                │
# │  Test:CausalMetricsprevalence_stratify_by_219   │               0.8288973384030506                │
# │  Test:CausalMetricsprevalence_stratify_by_220   │               0.8326996197718595                │
# │  Test:CausalMetricsprevalence_stratify_by_221   │               0.8365019011406819                │
# │  Test:CausalMetricsprevalence_stratify_by_222   │               0.8403041825095002                │
# │  Test:CausalMetricsprevalence_stratify_by_223   │               0.8441064638783322                │
# │  Test:CausalMetricsprevalence_stratify_by_224   │               0.8479087452471428                │
# │  Test:CausalMetricsprevalence_stratify_by_225   │               0.8517110266159725                │
# │  Test:CausalMetricsprevalence_stratify_by_226   │               0.8555133079847834                │
# │  Test:CausalMetricsprevalence_stratify_by_227   │               0.8593155893536092                │
# │  Test:CausalMetricsprevalence_stratify_by_228   │               0.8631178707224335                │
# │  Test:CausalMetricsprevalence_stratify_by_229   │               0.8669201520912636                │
# │  Test:CausalMetricsprevalence_stratify_by_230   │               0.8707224334600675                │
# │  Test:CausalMetricsprevalence_stratify_by_231   │               0.8745247148289041                │
# │  Test:CausalMetricsprevalence_stratify_by_232   │               0.8783269961977118                │
# │  Test:CausalMetricsprevalence_stratify_by_233   │               0.8821292775665415                │
# │  Test:CausalMetricsprevalence_stratify_by_234   │               0.8859315589353532                │
# │  Test:CausalMetricsprevalence_stratify_by_235   │               0.8897338403041877                │
# │  Test:CausalMetricsprevalence_stratify_by_236   │               0.8935361216729947                │
# │  Test:CausalMetricsprevalence_stratify_by_237   │               0.8973384030418267                │
# │  Test:CausalMetricsprevalence_stratify_by_238   │                0.901140684410634                │
# │  Test:CausalMetricsprevalence_stratify_by_239   │               0.9049429657794688                │
# │  Test:CausalMetricsprevalence_stratify_by_240   │               0.9087452471482781                │
# │  Test:CausalMetricsprevalence_stratify_by_241   │               0.9125475285171163                │
# │  Test:CausalMetricsprevalence_stratify_by_242   │               0.9163498098859406                │
# │  Test:CausalMetricsprevalence_stratify_by_243   │               0.9201520912547497                │
# │  Test:CausalMetricsprevalence_stratify_by_244   │               0.9239543726235859                │
# │  Test:CausalMetricsprevalence_stratify_by_245   │               0.9277566539923905                │
# │  Test:CausalMetricsprevalence_stratify_by_246   │               0.9315589353612244                │
# │  Test:CausalMetricsprevalence_stratify_by_247   │               0.9353612167300316                │
# │  Test:CausalMetricsprevalence_stratify_by_248   │               0.9391634980988669                │
# │  Test:CausalMetricsprevalence_stratify_by_249   │               0.9429657794676789                │
# │   Test:CausalMetricsprevalence_stratify_by_25   │               0.09125475285171103               │
# │  Test:CausalMetricsprevalence_stratify_by_250   │               0.9467680608365009                │
# │  Test:CausalMetricsprevalence_stratify_by_251   │                0.950570342205312                │
# │  Test:CausalMetricsprevalence_stratify_by_252   │               0.9543726235741544                │
# │  Test:CausalMetricsprevalence_stratify_by_253   │               0.9581749049429705                │
# │  Test:CausalMetricsprevalence_stratify_by_254   │                0.961977186311795                │
# │  Test:CausalMetricsprevalence_stratify_by_255   │               0.9657794676806072                │
# │  Test:CausalMetricsprevalence_stratify_by_256   │               0.9695817490494358                │
# │  Test:CausalMetricsprevalence_stratify_by_257   │               0.9733840304182505                │
# │  Test:CausalMetricsprevalence_stratify_by_258   │               0.9771863117870777                │
# │  Test:CausalMetricsprevalence_stratify_by_259   │               0.9809885931558822                │
# │  Test:CausalMetricsprevalence_stratify_by_260   │                0.984790874524719                │
# │  Test:CausalMetricsprevalence_stratify_by_261   │               0.9885931558935528                │
# │  Test:CausalMetricsprevalence_stratify_by_262   │               0.9923954372623227                │
# │  Test:CausalMetricsprevalence_stratify_by_263   │               0.9961977186311591                │
# │  Test:CausalMetricsprevalence_stratify_by_264   │                       1.0                       │
# │   Test:CausalMetricsprevalence_stratify_by_27   │               0.09885931558935361               │
# │   Test:CausalMetricsprevalence_stratify_by_31   │               0.11406844106463879               │
# │   Test:CausalMetricsprevalence_stratify_by_34   │               0.12547528517110265               │
# │   Test:CausalMetricsprevalence_stratify_by_38   │               0.14068441064638784               │
# │   Test:CausalMetricsprevalence_stratify_by_39   │               0.1444866920152091                │
# │   Test:CausalMetricsprevalence_stratify_by_40   │               0.1482889733840304                │
# │   Test:CausalMetricsprevalence_stratify_by_41   │               0.1520912547528517                │
# │   Test:CausalMetricsprevalence_stratify_by_44   │               0.1634980988593156                │
# │   Test:CausalMetricsprevalence_stratify_by_47   │               0.17490494296577946               │
# │   Test:CausalMetricsprevalence_stratify_by_48   │               0.17870722433460076               │
# │   Test:CausalMetricsprevalence_stratify_by_51   │               0.19011406844106463               │
# │   Test:CausalMetricsprevalence_stratify_by_55   │               0.20532319391634982               │
# │   Test:CausalMetricsprevalence_stratify_by_57   │               0.21292775665399238               │
# │   Test:CausalMetricsprevalence_stratify_by_58   │               0.21673003802281368               │
# │   Test:CausalMetricsprevalence_stratify_by_60   │               0.22433460076045628               │
# │   Test:CausalMetricsprevalence_stratify_by_63   │               0.23574144486692014               │
# │   Test:CausalMetricsprevalence_stratify_by_65   │               0.24334600760456274               │
# │   Test:CausalMetricsprevalence_stratify_by_67   │               0.2509505703422053                │
# │   Test:CausalMetricsprevalence_stratify_by_70   │               0.2623574144486692                │
# │   Test:CausalMetricsprevalence_stratify_by_71   │               0.2661596958174905                │
# │   Test:CausalMetricsprevalence_stratify_by_75   │               0.2813688212927757                │
# │   Test:CausalMetricsprevalence_stratify_by_78   │               0.29277566539923955               │
# │   Test:CausalMetricsprevalence_stratify_by_79   │               0.2965779467680608                │
# │   Test:CausalMetricsprevalence_stratify_by_80   │               0.3003802281368821                │
# │   Test:CausalMetricsprevalence_stratify_by_81   │               0.3041825095057034                │
# │   Test:CausalMetricsprevalence_stratify_by_82   │               0.30798479087452474               │
# │   Test:CausalMetricsprevalence_stratify_by_83   │                0.311787072243346                │
# │   Test:CausalMetricsprevalence_stratify_by_84   │               0.3155893536121673                │
# │   Test:CausalMetricsprevalence_stratify_by_85   │               0.3193916349809886                │
# │   Test:CausalMetricsprevalence_stratify_by_89   │               0.33460076045627374               │
# │   Test:CausalMetricsprevalence_stratify_by_91   │               0.34220532319391633               │
# │   Test:CausalMetricsprevalence_stratify_by_93   │                0.349809885931559                │
# │   Test:CausalMetricsprevalence_stratify_by_94   │               0.3536121673003801                │
# │   Test:CausalMetricsprevalence_stratify_by_95   │               0.3574144486692015                │
# │   Test:CausalMetricsprevalence_stratify_by_97   │               0.3650190114068441                │
# │   Test:CausalMetricsprevalence_stratify_by_98   │               0.3688212927756655                │
# │   Test:CausalMetricsprevalence_stratify_by_99   │               0.3726235741444867                │
# │                    test_acc                     │               0.7563223838806152                │
# │                    test_loss                    │               0.8293307423591614                │
# └─────────────────────────────────────────────────┴─────────────────────────────────────────────────┘
# Loaded model with 11.312201 M parameters

# %%
import matplotlib.pyplot as plt
import numpy as np
import wandb
import polars as pl
wandb.login()

# Load causal_eval results from log
api = wandb.Api()
run = api.run("cwlgadd/SurvivEHR/runs/1gyzrm07")

# %%
history = run.history(keys=None)
raw_data_from_wandb = {}
for key in history.keys():
    raw_data_from_wandb = {**raw_data_from_wandb, key: history[key].to_numpy()[-1]}
display(raw_data_from_wandb)
# Out:
# {'Test:_clfCintra42': 0.6221590909090909,
#  'Test:_prevalenceCintra97': 0.36501901140684373,
#  'Test:_clfCintra201': 0.3991222770007209,
#  'Test:_clfCintra234': 0.8622548865171152,
#  'Test:_prevalenceCintra128': 0.48288973384030853,
#  'Test:_clfCintra64': 0.2610588645071404,
#  'Test:_prevalenceCinter': 0.8595876432531979,
#  'Test:_prevalenceCintra257': 0.9733840304180014,
#  'Test:_prevalenceCintra248': 0.939163498099471,
#  'Test:_clfCintra14': 0.47777777777777775,
#  'Test:_clfCintra21': 0.35858585858585856,
#  'Test:_clfCintra43': 0.5701368523949168,
#  'Test:_prevalenceCintra227': 0.8593155893538502,
#  'Test:_prevalenceCintra254': 0.9619771863128516,
#  'Test:_prevalenceCintra28': 0.1026615969581749,
#  'Test:_clfCintra157': 0.3487940556645585,
#  'Test:_clfCintra130': 0.4214485095688359,
#  'Test:_prevalenceCintra171': 0.6463878326995584,
#  'Test:_prevalenceCintra9': 0.030418250950570335,
#  'Test:_prevalenceCintra219': 0.8288973384034037,
#  'Test:_clfCintra109': 0.8214413639945547,
#  'Test:_prevalenceCintra133': 0.5019011406843951,
#  'Test:_clfCintra233': 0.1235336775726066,
#  'Test:_prevalenceCintra43': 0.1596958174904942,
#  'Test:_prevalenceCintra23': 0.08365019011406848,
#  'Test:_clfCintra69': 0.5922619047619048,
#  'Test:_prevalenceCintra155': 0.5855513307984975,
#  'Test:_clfCintra259': 0.05526695251377475,
#  'Test:_clfCintra209': 0.7943014785119908,
#  'Test:_prevalenceCintra126': 0.4752851711026556,
#  'Test:_clfCintra101': 0.39786439051144923,
#  'Test:_prevalenceCintra60': 0.22433460076045614,
#  'Test:_prevalenceCintra240': 0.9087452471479102,
#  'Test:_prevalenceCintra245': 0.927756653992765,
#  'Test:_clfCintra57': 0.46777146464646485,
#  'Test:_prevalenceCintra24': 0.0874524714828898,
#  'Test:_clfCintra176': 0.03738375352847634,
#  'Test:_prevalenceCintra30': 0.11026615969581754,
#  'Test:_prevalenceCintra196': 0.741444866920278,
#  'Test:_clfCintra192': 0.7779366658376883,
#  'Test:_prevalenceCintra102': 0.3840304182509461,
#  'Test:_prevalenceCintra95': 0.35741444866920224,
#  'Test:_clfCintra161': 0.838921443683676,
#  'Test:_prevalenceCintra125': 0.47148288973384395,
#  'Test:_prevalenceCintra10': 0.03422053231939164,
#  'Test:_clfCintra110': 0.8130271243907603,
#  'Test:_clfCintra132': 0.6343054825713779,
#  'Test:_clfCintra52': 0.3977272727272727,
#  'Test:_clfCintra123': 0.10128801008350416,
#  'Test:_prevalenceCintra76': 0.28517110266159734,
#  'Test:_clfCintra92': 0.24266197540256138,
#  'Test:_clfCintra264': 0.5608446503265381,
#  'Test:_prevalenceCintra116': 0.437262357414453,
#  'Test:_clfCintra189': 0.5522351568517875,
#  'Test:_prevalenceCintra225': 0.8517110266157658,
#  'Test:_clfCintra203': 0.8430710834556993,
#  'Test:_prevalenceCintra166': 0.6273764258554595,
#  'Test:_clfCintra99': 0.6465486701547858,
#  'Test:_prevalenceCintra143': 0.5399239543726252,
#  'Test:_prevalenceCintra109': 0.4106463878327029,
#  'Test:_prevalenceCintra11': 0.03802281368821293,
#  'Test:_clfCintra153': 0.6497768143351712,
#  'Test:_prevalenceCintra22': 0.0798479087452471,
#  'Test:_prevalenceCintra135': 0.5095057034220615,
#  'Test:_clfCintra218': 0.8909436485710356,
#  'Test:_clfCintra190': 0.936591021657858,
#  'Test:_clfCintra72': 0.5720223063973067,
#  'Test:_prevalenceCintra178': 0.6730038022814435,
#  'Test:_prevalenceCintra246': 0.9315589353612028,
#  'Test:_prevalenceCintra19': 0.06844106463878324,
#  'Test:_prevalenceCintra103': 0.3878326996197722,
#  'Test:_prevalenceCintra113': 0.4258555133079857,
#  'Test:_prevalenceCintra226': 0.8555133079852734,
#  'Test:_clfCintra236': 0.766840668198932,
#  'Test:_clfCintra254': 0.11412373262131312,
#  'Test:_clfCintra243': 0.7677459759028974,
#  'Test:_prevalenceCintra72': 0.26996197718631226,
#  'Test:_prevalenceCintra21': 0.07604562737642585,
#  'Test:_prevalenceCintra136': 0.5133079847908869,
#  'Test:_prevalenceCintra177': 0.6692015209124759,
#  'Test:_prevalenceCintra57': 0.21292775665399247,
#  'Test:_prevalenceCintra105': 0.39543726235741217,
#  'Test:_clfCintra202': 0.16981527300218524,
#  'Test:_clfCintra20': 0.4463869463869464,
#  'Test:_prevalenceCintra259': 0.9809885931560609,
#  'Test:_prevalenceCintra199': 0.7528517110267274,
#  'Test:_clfCintra22': 0.4228896103896104,
#  'Test:_clfCintra115': 0.6319938515590694,
#  'Test:_clfCintra34': 0.6235667485667488,
#  'Test:_prevalenceCintra190': 0.7186311787072526,
#  'Test:_clfCintra112': 0.1464624274378232,
#  'Test:_clfCintra56': 0.08498622589531682,
#  'Test:_prevalenceCintra41': 0.15209125475285185,
#  'Test:_clfCintra171': 0.3673037993706023,
#  'Test:_prevalenceCintra212': 0.8022813688217456,
#  'Test:_clfCintra84': 0.5298029802980297,
#  'Test:_prevalenceCintra233': 0.8821292775670186,
#  'Test:_prevalenceCintra203': 0.7680608365018092,
#  'Test:_clfCintra93': 0.040503069914834725,
#  'Test:_clfCinter': 0.6985187044231772,
#  'Test:_clfCintra185': 0.9236057710564245,
#  'Test:_prevalenceCintra207': 0.783269961977451,
#  'Test:_clfCintra97': 0.2177683427683428,
#  'Test:_clfCintra241': 0.6567980970793708,
#  'Test:_prevalenceCintra96': 0.3612167300380235,
#  'Test:_prevalenceCintra152': 0.5741444866920452,
#  'Test:_prevalenceCintra231': 0.8745247148290106,
#  'Test:_prevalenceCintra211': 0.7984790874516,
#  'Test:_prevalenceCintra79': 0.2965779467680613,
#  'Test:_clfCintra51': 0.45241892610313666,
#  'Test:_prevalenceCintra230': 0.870722433460206,
#  'Test:_clfCintra225': 0.7095552424822821,
#  'Test:_prevalenceCintra228': 0.8631178707225414,
#  'Test:_clfCintra26': 0.08565244279529995,
#  'Test:_clfCintra24': 0.3572261072261072,
#  'Test:_clfCintra62': 0.41544230180593805,
#  'Test:_prevalenceCintra81': 0.3041825095057025,
#  'Test:_clfCintra87': 0.3540648419680678,
#  'Test:_clfCintra83': 0.729645135566188,
#  'Test:_clfCintra215': 0.9592637443387273,
#  'Test:_clfCintra12': 0.4043148880105401,
#  'Test:_clfCintra91': 0.05791030745410314,
#  'Test:_prevalenceCintra17': 0.0608365019011407,
#  'Test:_prevalenceCintra37': 0.13688212927756643,
#  'Test:_prevalenceCintra108': 0.40684410646387886,
#  'Test:_prevalenceCintra87': 0.3269961977186293,
#  'Test:_prevalenceCintra194': 0.733840304182432,
#  'Test:_clfCintra256': 0.9478758841644861,
#  'Test:_prevalenceCintra66': 0.24714828897338467,
#  'Test:_clfCintra118': 0.6805652457033867,
#  'Test:_clfCintra37': 0.2715400271370421,
#  'Test:_clfCintra116': 0.43628663431024783,
#  'Test:_prevalenceCintra55': 0.20532319391634982,
#  'Test:_prevalenceCintra256': 0.9695817490498626,
#  'Test:_clfCintra206': 0.7639514362659715,
#  'Test:_prevalenceCintra242': 0.9163498098860116,
#  'Test:_prevalenceCintra222': 0.8403041825095461,
#  'Test:_clfCintra85': 0.3147140418267178,
#  'Test:_prevalenceCintra186': 0.7034220532320952,
#  'Test:_prevalenceCintra85': 0.3193916349809883,
#  'Test:_clfCintra111': 0.9701101928374709,
#  'Test:_prevalenceCintra217': 0.8212927756651128,
#  'Test:_prevalenceCintra149': 0.5627376425855329,
#  'Test:_prevalenceCintra107': 0.40304182509505815,
#  'Test:_prevalenceCintra63': 0.23574144486692014,
#  'Test:_prevalenceCintra181': 0.6844106463877504,
#  'Test:_clfCintra134': 0.8607257585988154,
#  'Test:_prevalenceCintra249': 0.9429657794679374,
#  'Test:_clfCintra40': 0.41769972451790655,
#  'Test:_clfCintra150': 0.7190287059219096,
#  'Test:_prevalenceCintra47': 0.17490494296577944,
#  'Test:_prevalenceCintra221': 0.8365019011404103,
#  'Test:_clfCintra80': 0.30043653590165226,
#  'Test:_prevalenceCintra71': 0.26615969581748994,
#  'Test:_prevalenceCintra173': 0.6539923954372296,
#  'Test:_prevalenceCintra14': 0.04942965779467679,
#  'Test:_prevalenceCintra162': 0.6121673003802359,
#  'Test:_prevalenceCintra61': 0.22813688212927732,
#  'Test:_clfCintra142': 0.242420575552231,
#  'Test:_prevalenceCintra75': 0.2813688212927748,
#  'Test:_clfCintra210': 0.8157530799040241,
#  'Test:_prevalenceCintra146': 0.5513307984790773,
#  'Test:_prevalenceCintra129': 0.48669201520912914,
#  'Test:_clfCintra214': 0.6543191907196481,
#  'Test:_prevalenceCintra56': 0.20912547528517128,
#  'Test:_clfCintra126': 0.07896341463414629,
#  'Test:_prevalenceCintra243': 0.920152091254428,
#  'Test:_clfCintra82': 0.580615121312796,
#  'Test:_clfCintra260': 0.7961727443211964,
#  'Test:_prevalenceCintra209': 0.7908745247150004,
#  'Test:_prevalenceCintra180': 0.6806083650189979,
#  'Test:_clfCintra133': 0.3631459858524069,
#  'Test:_prevalenceCintra218': 0.8250950570344606,
#  'Test:_clfCintra139': 0.9929851398601143,
#  'Test:_prevalenceCintra172': 0.6501901140685205,
#  'Test:_prevalenceCintra182': 0.6882129277565351,
#  'Test:_prevalenceCintra104': 0.3916349809885901,
#  'Test:_clfCintra231': 0.8820585265264673,
#  'Test:_prevalenceCintra92': 0.34600760456273805,
#  'Test:_prevalenceCintra99': 0.3726235741444844,
#  'Test:_clfCintra163': 0.09376466906587151,
#  'Test:_prevalenceCintra115': 0.4334600760456309,
#  'Test:_prevalenceCintra137': 0.5171102661597003,
#  'Test:_clfCintra104': 0.5482071519049011,
#  'Test:_prevalenceCintra118': 0.444866920152094,
#  'Test:_prevalenceCintra58': 0.21673003802281404,
#  'Test:_clfCintra96': 0.3340518770846636,
#  'Test:_clfCintra198': 0.869337529666698,
#  'Test:_clfCintra71': 0.5519682809402435,
#  'Test:_prevalenceCintra148': 0.5589353612167498,
#  'Test:_prevalenceCintra6': 0.019011406844106463,
#  'Test:_clfCintra23': 0.6287878787878787,
#  'Test:_prevalenceCintra64': 0.2395437262357429,
#  'Test:_clfCintra232': 0.8550573773091742,
#  'Test:_prevalenceCintra235': 0.8897338403039746,
#  'Test:_prevalenceCintra31': 0.11406844106463876,
#  'test_acc': 0.7585042715072632,
#  '_step': 0,
#  'Test:_clfCintra196': 0.7531960933123691,
#  'Test:_prevalenceCintra94': 0.35361216730038286,
#  'Test:_clfCintra141': 0.4494032962342828,
#  'Test:_clfCintra124': 0.7544182861614707,
#  'Test:_clfCintra204': 0.3927377871672666,
#  'Test:_clfCintra100': 0.11564337403889634,
#  'Test:_clfCintra143': 0.13096047759389387,
#  'Test:_prevalenceCintra204': 0.7718631178706007,
#  'Test:_clfCintra16': 0.23261019283746556,
#  'Test:_prevalenceCintra25': 0.09125475285171103,
#  'Test:_clfCintra174': 0.5473821785268419,
#  'Test:_clfCintra217': 0.7315820100392114,
#  'Test:_clfCintra147': 0.7119763653854563,
#  'Test:_clfCintra167': 0.5265114041083563,
#  'Test:_clfCintra131': 0.5608955223880598,
#  'Test:_clfCintra78': 0.12091772648767467,
#  'Test:_clfCintra179': 0.5981614381418051,
#  'Test:_prevalenceCintra70': 0.2623574144486705,
#  'Test:_prevalenceCintra163': 0.6159695817490946,
#  'Test:_prevalenceCintra20': 0.07224334600760454,
#  'Test:_clfCintra105': 0.6519584966710221,
#  'Test:_clfCintra148': 0.48385413329916493,
#  'Test:_clfCintra31': 0.32168911335578004,
#  'Test:_clfCintra252': 0.88160007003255,
#  'Test:_prevalenceCintra7': 0.022813688212927757,
#  'Test:_prevalenceCintra258': 0.9771863117866503,
#  'Test:_prevalenceCintra168': 0.6349809885931308,
#  'Test:_clfCintra94': 0.509800202326758,
#  'Test:_clfCintra77': 0.39579640415295003,
#  'Test:_clfCintra32': 0.4444073083778966,
#  'Test:_prevalenceCintra206': 0.7794676806080363,
#  'Test:_clfCintra160': 0.27892994837109114,
#  'Test:_clfCintra74': 0.24454652912099709,
#  'Test:_clfCintra47': 0.3645833333333333,
#  'Test:_prevalenceCintra44': 0.1634980988593157,
#  'Test:_clfCintra238': 0.8483968947174517,
#  'Test:_prevalenceCintra123': 0.4638783269962143,
#  'Test:_clfCintra154': 0.06499533915187504,
#  'trainer/global_step': 0,
#  'Test:_clfCintra65': 0.3396745230078564,
#  'Test:_clfCintra221': 0.24830585738556105,
#  'Test:_clfCintra36': 0.6060606060606059,
#  'Test:_clfCintra119': 0.6440188599279516,
#  'Test:_clfCintra48': 0.2534526682756772,
#  'Test:_clfCintra127': 0.7535072951739624,
#  'Test:_clfCintra63': 0.6786130536130537,
#  'Test:_clfCintra156': 0.7211383618967026,
#  'Test:_prevalenceCintra68': 0.2547528517110262,
#  'Test:_clfCintra27': 0.2518939393939394,
#  'Test:_prevalenceCintra93': 0.34980988593156,
#  'Test:_clfCintra213': 0.2730418202073857,
#  'Test:_clfCintra15': 0.13852813852813853,
#  'Test:_clfCintra228': 0.6192650909441213,
#  'Test:_prevalenceCintra202': 0.7642585551329927,
#  'Test:_prevalenceCintra250': 0.9467680608361443,
#  'Test:_prevalenceCintra39': 0.14448669201520883,
#  'Test:_clfCintra67': 0.2685286600949252,
#  'Test:_clfCintra205': 0.3153053401893423,
#  'Test:_prevalenceCintra150': 0.5665399239544052,
#  'Test:_prevalenceCintra106': 0.3992395437262434,
#  'Test:_clfCintra258': 0.9961680635765437,
#  'Test:_clfCintra248': 0.8992203245996425,
#  'Test:_clfCintra17': 0.5456002331002331,
#  'Test:_clfCintra194': 0.8571482321482387,
#  'Test:_prevalenceCintra52': 0.19391634980988573,
#  'Test:_clfCintra2': 0,
#  'Test:_prevalenceCintra86': 0.32319391634980865,
#  'Test:_prevalenceCintra160': 0.6045627376425141,
#  'Test:_prevalenceCintra158': 0.5969581749049565,
#  'Test:_clfCintra246': 0.9930155369124928,
#  'Test:_prevalenceCintra261': 0.9885931558953227,
#  'Test:_clfCintra165': 0.6197762705001001,
#  'Test:_prevalenceCintra67': 0.25095057034220514,
#  'Test:_prevalenceCintra119': 0.44866920152090467,
#  'Test:_clfCintra61': 0.20394736842105277,
#  'Test:_prevalenceCintra48': 0.17870722433460065,
#  'Test:_clfCintra140': 0.8561934277843367,
#  'Test:_prevalenceCintra100': 0.3764258555133074,
#  'Test:_prevalenceCintra200': 0.7566539923954884,
#  'Test:_prevalenceCintra223': 0.8441064638787985,
#  'Test:_prevalenceCintra18': 0.06463878326996197,
#  'Test:_clfCintra149': 0.22721523838724492,
#  'Test:_clfCintra129': 0.2708263446270828,
#  'Test:_prevalenceCintra205': 0.7756653992395559,
#  'Test:_clfCintra86': 0.2945702157764413,
#  'Test:_clfCintra152': 0.24789246317024022,
#  'Test:_clfCintra120': 0.4483598430966852,
#  'Test:_prevalenceCintra198': 0.7490494296578073,
#  'Test:_prevalenceCintra176': 0.6653992395438166,
#  'Test:_prevalenceCintra29': 0.1064638783269962,
#  'Test:_clfCintra212': 0.6376248813179854,
#  'Test:_prevalenceCintra78': 0.2927756653992402,
#  'Test:_prevalenceCintra35': 0.12927756653992414,
#  'Test:_clfCintra195': 0.09302319375237293,
#  'Test:_prevalenceCintra84': 0.315589353612168,
#  'Test:_clfCintra44': 0.15251377410468311,
#  'Test:_prevalenceCintra141': 0.5323193916349843,
#  'Test:_prevalenceCintra140': 0.5285171102661661,
#  'Test:_prevalenceCintra38': 0.1406844106463881,
#  'Test:_clfCintra255': 0.9475480458753943,
#  'Test:_prevalenceCintra124': 0.46768060836501596,
#  'Test:_clfCintra191': 0.3986811799311801,
#  'Test:_prevalenceCintra264': 1,
#  'Test:_prevalenceCintra238': 0.9011406844107437,
#  'Test:_prevalenceCintra251': 0.9505703422042567,
#  'Test:_clfCintra68': 0.5077257725772578,
#  'Test:_prevalenceCintra5': 0.015209125475285171,
#  'Test:_clfCintra249': 0.9037210648148112,
#  'Test:_prevalenceCintra46': 0.17110266159695806,
#  'Test:_prevalenceCintra263': 0.996197718631749,
#  'Test:_clfCintra121': 0.7376544647292603,
#  'Test:_clfCintra5': 0.34375,
#  'Test:_prevalenceCintra262': 0.9923954372634197,
#  'Test:_prevalenceCintra220': 0.8326996197720141,
#  'Test:_clfCintra222': 0.7995819084081413,
#  'Test:_prevalenceCintra247': 0.9353612167300867,
#  'Test:_clfCintra58': 0.7176954201101925,
#  'Test:_clfCintra13': 0.4753787878787879,
#  'Test:_clfCintra250': 0.5902898327504533,
#  'Test:_clfCintra75': 0.775673400673401,
#  'Test:_prevalenceCintra73': 0.27376425855513287,
#  'Test:_clfCintra237': 0.8703763790057102,
#  'Test:_prevalenceCintra239': 0.9049429657794203,
#  'Test:_clfCintra199': 0.868822582339824,
#  'Test:_clfCintra187': 0.9410177118662261,
#  'Test:_clfCintra242': 0.6015251154151713,
#  'Test:_clfCintra207': 0.7890423947692964,
#  'Test:_prevalenceCintra216': 0.817490494296592,
#  'Test:_clfCintra146': 0.5021948993988468,
#  'Test:_clfCintra151': 0.6153879463396499,
#  'Test:_prevalenceCintra42': 0.15589353612167303,
#  'Test:_clfCintra244': 0.8714776918799217,
#  'Test:_prevalenceCintra191': 0.7224334600759965,
#  'Test:_clfCintra208': 0.6203377340595018,
#  'Test:_prevalenceCintra98': 0.36882129277566417,
#  'Test:_clfCintra178': 0.4853702233839206,
#  'Test:_prevalenceCintra197': 0.7452471482891091,
#  'Test:_clfCintra211': 0.3301519999085805,
#  'Test:_prevalenceCintra127': 0.4790874524714873,
#  'Test:_prevalenceCintra74': 0.2775665399239536,
#  'Test:_clfCintra25': 0.33181818181818185,
#  'Test:_clfCintra54': 0.03855866355866355,
#  'Test:_clfCintra193': 0.833959833159281,
#  'Test:_prevalenceCintra117': 0.44106463878326674,
#  'Test:_clfCintra227': 0.6996552543984769,
#  'Test:_clfCintra177': 0.7168111472944374,
#  'Test:_clfCintra170': 0.33730657074136355,
#  'Test:_prevalenceCintra224': 0.8479087452470051,
#  'Test:_prevalenceCintra91': 0.3422053231939182,
#  'Test:_clfCintra79': 0.6761520160280498,
#  'Test:_clfCintra38': 0.3129117259552043,
#  'Test:_clfCintra169': 0.7561439658897274,
#  'Test:_clfCintra224': 0.89242719855525,
#  'Test:_clfCintra46': 0.48301985370950895,
#  'Test:_clfCintra188': 0.28348442453447936,
#  'Test:_prevalenceCintra50': 0.1863117870722428,
#  'Test:_clfCintra76': 0.3465227817745803,
#  'Test:_clfCintra223': 0.5094289372260893,
#  'Test:_prevalenceCintra62': 0.23193916349809854,
#  'Test:_clfCintra219': 0.48966032757540895,
#  'Test:_prevalenceCintra184': 0.6958174904941752,
#  'Test:_clfCintra55': 0.5887445887445886,
#  'Test:_clfCintra98': 0.6129555180910389,
#  'Test:_prevalenceCintra139': 0.5247148288973443,
#  'Test:_prevalenceCintra13': 0.045627376425855515,
#  'Test:_clfCintra90': 0.49353406678247425,
#  'Test:_prevalenceCintra49': 0.1825095057034219,
#  'Test:_prevalenceCintra193': 0.7300380228136545,
#  'Test:_prevalenceCintra232': 0.8783269961972752,
#  'Test:_clfCintra200': 0.8442660226274038,
#  'Test:_clfCintra117': 0.07127592772646234,
#  'Test:_prevalenceCintra131': 0.4942965779467774,
#  'Test:_prevalenceCintra65': 0.24334600760456218,
#  'Test:_prevalenceCintra69': 0.2585551330798479,
#  'Test:_prevalenceCintra122': 0.4600760456273748,
#  'Test:_clfCintra216': 0.6434143333659283,
#  'Test:_prevalenceCintra112': 0.42205323193917055,
#  'Test:_prevalenceCintra8': 0.02661596958174905,
#  'Test:_clfCintra251': 0.6772079091926068,
#  'Test:_clfCintra240': 0.9670193224261968,
#  'Test:_clfCintra175': 0.7246087951862256,
#  'Test:_clfCintra8': 0.1534090909090909,
#  'Test:_prevalenceCintra59': 0.22053231939163473,
#  'Test:_clfCintra89': 0.01614704739704746,
#  'Test:_clfCintra102': 0.8901949826130144,
#  'Test:_prevalenceCintra210': 0.794676806083582,
#  'Test:_clfCintra262': 0.9707778429086282,
#  'Test:_prevalenceCintra111': 0.4182509505703453,
#  'Test:_clfCintra144': 0.09594171173491309,
#  'Test:_prevalenceCintra80': 0.30038022813688403,
#  'Test:_clfCintra18': 0.271969696969697,
#  'Test:_prevalenceCintra15': 0.0532319391634981,
#  'Test:_clfCintra173': 0.5835407726127583,
#  'Test:_prevalenceCintra234': 0.8859315589359222,
#  'Test:_clfCintra19': 0.43311688311688307,
#  'Test:_prevalenceCintra2': 0.0038022813688212928,
#  'Test:_clfCintra235': 0.8099852781561544,
#  'Test:_clfCintra11': 0.41603535353535354,
#  'Test:_prevalenceCintra144': 0.5437262357414305,
#  'Test:_prevalenceCintra187': 0.707224334600859,
#  'Test:_clfCintra30': 0.6127840909090909,
#  'Test:_prevalenceCintra40': 0.1482889733840303,
#  'Test:_prevalenceCintra170': 0.6425855513307716,
#  'Test:_clfCintra81': 0.17530776515151522,
#  'Test:_prevalenceCintra32': 0.11787072243346006,
#  'Test:_prevalenceCintra83': 0.31178707224334656,
#  'Test:_prevalenceCintra215': 0.8136882129275462,
#  'Test:_clfCintra6': 0.1830808080808081,
#  'Test:_prevalenceCintra90': 0.33840304182509573,
#  'Test:_prevalenceCintra253': 0.9581749049430061,
#  'Test:_clfCintra95': 0.78389960208142,
#  'Test:_prevalenceCintra33': 0.12167300380228142,
#  'Test:_prevalenceCintra89': 0.3346007604562722,
#  'Test:_prevalenceCintra244': 0.9239543726240194,
#  'Test:_prevalenceCintra151': 0.5703422053231868,
#  'Test:_prevalenceCintra179': 0.6768060836502502,
#  'Test:_prevalenceCintra121': 0.4562737642585667,
#  'Test:_prevalenceCintra82': 0.3079847908745267,
#  'Test:_clfCintra138': 0.5972419123003915,
#  'Test:_clfCintra183': 0.8006361663754722,
#  'Test:_clfCintra158': 0.7047461555857096,
#  'Test:_clfCintra106': 0.04770898641588274,
#  'Test:_clfCintra45': 0.21489898989898984,
#  'Test:_prevalenceCintra192': 0.7262357414447862,
#  'Test:_prevalenceCintra213': 0.8060836501900136,
#  'Test:_prevalenceCintra16': 0.057034220532319393,
#  'Test:_clfCintra186': 0.5893143645509566,
#  'Test:_prevalenceCintra156': 0.5893536121673114,
#  'Test:_clfCintra113': 0.4734133790737561,
#  'Test:_prevalenceCintra165': 0.6235741444866445,
#  'Test:_clfCintra166': 0.3808467730392921,
#  'Test:_prevalenceCintra110': 0.4144486692015274,
#  'Test:_prevalenceCintra36': 0.1330798479087453,
#  'Test:_prevalenceCintra147': 0.5551330798479058,
#  'Test:_prevalenceCintra260': 0.9847908745239266,
#  'Test:_prevalenceCintra169': 0.6387832699620017,
#  'Test:_clfCintra128': 0.25095272635166227,
#  'Test:_prevalenceCintra255': 0.9657794676814734,
#  'Test:_prevalenceCintra101': 0.3802281368821285,
#  'Test:_prevalenceCintra142': 0.5361216730037919,
#  'Test:_clfCintra41': 0.4854166666666666,
#  'Test:_prevalenceCintra174': 0.6577946768061236,
#  'Test:_clfCintra137': 0.5992340992341,
#  'Test:_clfCintra239': 0.9437663903352878,
#  'Test:_clfCintra73': 0.13026367571822117,
#  'Test:_prevalenceCintra195': 0.7376425855512799,
#  'Test:_clfCintra155': 0.8506413458336538,
#  'Test:_clfCintra136': 0.6157232635383296,
#  'Test:_clfCintra59': 0.2461448807602652,
#  'Test:_prevalenceCintra164': 0.6197718631178465,
#  'Test:_prevalenceCintra54': 0.20152091254752813,
#  'Test:_prevalenceCintra183': 0.6920152091255211,
#  'Test:_prevalenceCintra132': 0.498098859315581,
#  'Test:_clfCintra9': 0.38906926406926395,
#  'Test:_clfCintra230': 0.7768440091759251,
#  'Test:_clfCintra35': 0.5612041467304626,
#  'Test:_prevalenceCintra159': 0.6007604562737482,
#  'Test:_clfCintra70': 0.08701695857659168,
#  'Test:_clfCintra29': 0.6199494949494949,
#  'Test:_clfCintra159': 0.016952849757991634,
#  'Test:_clfCintra103': 0.18451046337817645,
#  'Test:_prevalenceCintra201': 0.7604562737647659,
#  'Test:_clfCintra114': 0.30654082667680976,
#  'Test:_clfCintra182': 0.5321663739069521,
#  'Test:_clfCintra181': 0.980122383881721,
#  'Test:_prevalenceCintra134': 0.5057034220532233,
#  'Test:_clfCintra107': 0.6214349376114089,
#  'Test:_prevalenceCintra45': 0.16730038022813695,
#  'Test:_prevalenceCintra185': 0.6996197718630884,
#  'Test:_prevalenceCintra161': 0.6083650190114165,
#  'Test:_prevalenceCintra237': 0.8973384030421773,
#  'Test:_prevalenceCintra120': 0.45247148288973443,
#  'Test:_clfCintra162': 0.9339749554579282,
#  '_timestamp': 1747836369.0171008,
#  'Test:_clfCintra60': 0.13282828282828282,
#  'Test:_prevalenceCintra51': 0.1901140684410645,
#  'Test:_prevalenceCintra145': 0.5475285171102999,
#  'Test:_clfCintra261': 0.9474195694263238,
#  'Test:_prevalenceCintra34': 0.1254752851711026,
#  'Test:_clfCintra247': 0.32145330221767965,
#  'Test:_clfCintra135': 0.5440823711172555,
#  'Test:_clfCintra184': 0.35859577512444796,
#  'Test:_prevalenceCintra252': 0.9543726235742869,
#  'Test:_clfCintra229': 0.7482243739575887,
#  'Test:_clfCintra220': 0.913723977165547,
#  'Test:_clfCintra3': 0.020833333333333336,
#  '_runtime': 10992.03172492981,
#  'Test:_clfCintra180': 0.985058006713134,
#  'Test:_clfCintra33': 0.6055749805749804,
#  'Test:_clfCintra245': 0.7231612690957977,
#  'Test:_clfCintra257': 0.9595565659812998,
#  'Test:_prevalenceCintra167': 0.6311787072243915,
#  'Test:_clfCintra108': 0.36489898989899,
#  'Test:_clfCintra145': 0.20888999795249846,
#  'Test:_clfCintra253': 0.8381315722454638,
#  'Test:_clfCintra197': 0.901835729229944,
#  'Test:_clfCintra7': 0.3106060606060606,
#  'Test:_clfCintra122': 0.6600900392599387,
#  'Test:_prevalenceCintra214': 0.8098859315589959,
#  'Test:_prevalenceCintra157': 0.593155893536217,
#  'Test:_prevalenceCintra154': 0.581749049429628,
#  'Test:_prevalenceCintra3': 0.0076045627376425855,
#  'Test:_clfCintra164': 0.7376581545312918,
#  'Test:_clfCintra226': 0.799411571123977,
#  'Test:_clfCintra172': 0.7519947415508763,
#  'Test:_prevalenceCintra114': 0.42965779467681053,
#  'Test:_prevalenceCintra77': 0.2889733840304167,
#  'Test:_clfCintra39': 0.7122200263504611,
#  'Test:_prevalenceCintra26': 0.09505703422053229,
#  'Test:_clfCintra28': 0.3072916666666667,
#  'Test:_clfCintra168': 0.7445683428413676,
#  'Test:_prevalenceCintra175': 0.6615969581748752,
#  'Test:_prevalenceCintra153': 0.5779467680608747,
#  'Test:_prevalenceCintra27': 0.09885931558935368,
#  'Test:_prevalenceCintra208': 0.7870722433459179,
#  'Test:_prevalenceCintra229': 0.8669201520907975,
#  'Test:_prevalenceCintra88': 0.33079847908745386,
#  'Test:_clfCintra125': 0.7787608225108216,
#  'Test:_prevalenceCintra138': 0.5209125475285038,
#  'Test:_prevalenceCintra241': 0.912547528517595,
#  'Test:_clfCintra10': 0.32196969696969696,
#  'test_loss': 0.8285166621208191,
#  'Test:_clfCintra66': 0.4477272727272728,
#  'Test:_prevalenceCintra188': 0.7110266159696854,
#  'Test:_prevalenceCintra189': 0.71482889733848,
#  'Test:_clfCintra88': 0.7253484038243396,
#  'epoch': 0,
#  'Test:_clfCintra49': 0.6521349862258955,
#  'Test:_prevalenceCintra236': 0.8935361216724477,
#  'Test:_clfCintra50': 0.27766299357208446,
#  'Test:_prevalenceCintra130': 0.4904942965779379,
#  'Test:_prevalenceCintra12': 0.04182509505703424,
#  'Test:_clfCintra263': 0.783764223582449}

# %%
valued_events = dm.meta_information["measurement_tables"][dm.meta_information["measurement_tables"]["count_obs"] > 0]["event"].to_list()
non_valued_events = dm.meta_information["measurement_tables"][dm.meta_information["measurement_tables"]["count_obs"] == 0]["event"].to_list()
diagnoses = dm.meta_information["diagnosis_table"]["event"].to_list()

# print(valued_events)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 valued_events = dm.meta_information["measurement_tables"][dm.meta_information["measurement_tables"]["count_obs"] > 0]["event"].to_list()
#       2 non_valued_events = dm.meta_information["measurement_tables"][dm.meta_information["measurement_tables"]["count_obs"] == 0]["event"].to_list()
#       3 diagnoses = dm.meta_information["diagnosis_table"]["event"].to_list()
#
# NameError: name 'dm' is not defined

# %%
Cinter_keys = [_key for _key in raw_data_from_wandb.keys() if "Test:_clfCintra" in _key ]

decoded_cintra_diagnoses = {}
decoded_cintra_non_valued = {}
decoded_cintra_valued = {}

for _key in Cinter_keys:
    _event = int(_key[len("Test:_clfCintra"):])                 # token
    _event_name = dm.decode([_event]).split(" ")[0]         # string
    _event_cintra = raw_data_from_wandb[_key]               # concordance

    if _event_name in diagnoses:# .upper() == _event_name:
        decoded_cintra_diagnoses = {**decoded_cintra_diagnoses, _event_name: _event_cintra}
    elif _event_name in non_valued_events:
        decoded_cintra_non_valued = {**decoded_cintra_non_valued, _event_name: _event_cintra}
    elif _event_name in valued_events:
        decoded_cintra_valued = {**decoded_cintra_valued, _event_name: _event_cintra}
    else:
        raise NotImplementedError

# %%
BaseCinter_keys = [_key for _key in raw_data_from_wandb.keys() if "Test:_prevalenceCintra" in _key ]

base_decoded_cintra_diagnoses = {}
base_decoded_cintra_non_valued = {}
base_decoded_cintra_valued = {}

base_prevalence_diagnoses = {}
base_prevalence_non_valued = {}
base_prevalence_valued = {}


for _key in BaseCinter_keys:
    _event = int(_key[len("Test:_prevalenceCintra"):])                 # token
    _event_name = dm.decode([_event]).split(" ")[0]         # string
    _event_cintra = raw_data_from_wandb[_key]               # concordance

    prevalence = dm.tokenizer._event_counts
    prevalence = prevalence.filter(pl.col("EVENT") ==_event_name)["COUNT"][0]

    if _event_name in diagnoses: #.upper() == _event_name:
        base_decoded_cintra_diagnoses = {**base_decoded_cintra_diagnoses, _event_name: _event_cintra}
        base_prevalence_diagnoses = {**base_prevalence_diagnoses, _event_name: prevalence}
        
    elif _event_name in non_valued_events:
        base_decoded_cintra_non_valued = {**base_decoded_cintra_non_valued, _event_name: _event_cintra}
        base_prevalence_non_valued = {**base_prevalence_non_valued, _event_name: prevalence}

    elif _event_name in valued_events:
        base_decoded_cintra_valued = {**base_decoded_cintra_valued, _event_name: _event_cintra}
        base_prevalence_valued = {**base_prevalence_valued, _event_name: prevalence}

    else:
        raise NotImplementedError

# %%
keys_included_diagnoses = list(set(base_decoded_cintra_diagnoses.keys()) & set(decoded_cintra_diagnoses.keys()))
keys_included_non_valued = list(set(base_decoded_cintra_non_valued.keys()) & set(decoded_cintra_non_valued.keys()))
keys_included_valued = list(set(base_decoded_cintra_valued.keys()) & set(decoded_cintra_valued.keys()))

# %%
for dict_name, result_dict, result_dict_base, result_dict_prev, keys_to_include in zip(["diagnoses", "medications", "measurements"],
                                                                     [decoded_cintra_diagnoses, decoded_cintra_non_valued, decoded_cintra_valued], 
                                                                     [base_decoded_cintra_diagnoses, base_decoded_cintra_non_valued, base_decoded_cintra_valued], 
                                                                     [base_prevalence_diagnoses, base_prevalence_non_valued, base_prevalence_valued],
                                                                     [keys_included_diagnoses, keys_included_non_valued, keys_included_valued]
                                                                     ):
    plt.close()
    # plt.figure(figsize=(len(keys_to_include)/5,5))
    fig, ax1 = plt.subplots(figsize=(len(keys_to_include)/4,8))
    ax2 = ax1.twinx()  

    X_axis = np.arange(len(keys_to_include)) 

    Y_base = [result_dict_base[_key] for _key in keys_to_include]
    Y_survivEHR = [result_dict[_key] for _key in keys_to_include]
    Y_log_prevalence = [np.log(result_dict_prev[_key]) for _key in keys_to_include]

    # Sort by prevalence
    arg_sort = np.argsort(Y_log_prevalence)
    Y_base = [Y_base[_i] for _i in arg_sort]
    Y_survivEHR = [Y_survivEHR[_i] for _i in arg_sort]
    Y_log_prevalence = [Y_log_prevalence[_i] for _i in arg_sort]
    keys_to_include = [keys_to_include[_i] for _i in arg_sort]

    width = 0.25
    ax1.bar(X_axis - width, Y_base, width, label = f'Concordance by prevalence (Average over events: {raw_data_from_wandb["Test:_prevalenceCinter"]:.3f})', color="mediumblue") 
    ax1.bar(X_axis, Y_survivEHR, width, label = f'Concordance by TransformerMLP (Average over events: {raw_data_from_wandb["Test:_clfCinter"]:.3f})', color="firebrick") 
    ax2.plot(X_axis, Y_log_prevalence, width, label='Log-prevalence', color="darkseagreen", marker=".")  #  + width

    ax1.set_xticks(X_axis, keys_to_include, rotation=90) 
    # ax1.xticks(X_axis, keys_to_include) 
    ax1.set_xlabel("Events") 
    ax1.set_ylabel("Self-supervised Concordance") 
    ax2.set_ylabel("Log Prevalence") 
    ax1.legend(loc="upper left")
    ax2.legend(loc="upper right")
    ax1.set_ylim(0, 1.2)
    ax2.set_ylim(np.min(Y_log_prevalence)*0.95, np.max(Y_log_prevalence)*1.1)
    

    # plt.bar(result_dict.keys(), result_dict.values(), 0.5, color='g')
    # ax1.xticks()

    # ybar = raw_data_from_wandb["Test:Cinter"]
    # ax1.plot([0, len(result_dict)-1], 
    #          [ybar, ybar],
    #          label=f"SurvivEHR marginalised over events",
    #          color="firebrick")

    # ybar = raw_data_from_wandb["Test:base_Cinter"]
    # ax1.plot([0, len(result_dict)-1], 
    #          [ybar, ybar],
    #          label=f"Prevalence marginalised over events",
    #          color="mediumblue")
    
    plt.tight_layout()
    plt.savefig(f"figs/inter_causal_eval_{dict_name}.png", bbox_inches="tight")
    plt.close()
